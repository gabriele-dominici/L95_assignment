# %% [markdown]
# # Comparing LAL parser and AJ parser

# %% [markdown]
# ### Install additional modules

# %%
# !pip install PyStanfordDependencies
# !pip install PYEVALB
# !pip install apted
# !pip install stanza
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: PyStanfordDependencies in /usr/local/lib/python3.8/dist-packages (0.3.1)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: PYEVALB in /usr/local/lib/python3.8/dist-packages (0.1.3)
# Requirement already satisfied: pytablewriter>=0.10.2 in /usr/local/lib/python3.8/dist-packages (from PYEVALB) (0.64.2)
# Requirement already satisfied: typepy[datetime]<2,>=1.2.0 in /usr/local/lib/python3.8/dist-packages (from pytablewriter>=0.10.2->PYEVALB) (1.3.0)
# Requirement already satisfied: setuptools>=38.3.0 in /usr/local/lib/python3.8/dist-packages (from pytablewriter>=0.10.2->PYEVALB) (57.4.0)
# Requirement already satisfied: tabledata<2,>=1.3.0 in /usr/local/lib/python3.8/dist-packages (from pytablewriter>=0.10.2->PYEVALB) (1.3.0)
# Requirement already satisfied: mbstrdecoder<2,>=1.0.0 in /usr/local/lib/python3.8/dist-packages (from pytablewriter>=0.10.2->PYEVALB) (1.1.1)
# Requirement already satisfied: pathvalidate<3,>=2.3.0 in /usr/local/lib/python3.8/dist-packages (from pytablewriter>=0.10.2->PYEVALB) (2.5.2)
# Requirement already satisfied: tcolorpy<1,>=0.0.5 in /usr/local/lib/python3.8/dist-packages (from pytablewriter>=0.10.2->PYEVALB) (0.1.2)
# Requirement already satisfied: DataProperty<2,>=0.55.0 in /usr/local/lib/python3.8/dist-packages (from pytablewriter>=0.10.2->PYEVALB) (0.55.0)
# Requirement already satisfied: chardet<6,>=3.0.4 in /usr/local/lib/python3.8/dist-packages (from mbstrdecoder<2,>=1.0.0->pytablewriter>=0.10.2->PYEVALB) (4.0.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.8/dist-packages (from typepy[datetime]<2,>=1.2.0->pytablewriter>=0.10.2->PYEVALB) (21.3)
# Requirement already satisfied: pytz>=2018.9 in /usr/local/lib/python3.8/dist-packages (from typepy[datetime]<2,>=1.2.0->pytablewriter>=0.10.2->PYEVALB) (2022.7)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.8.0 in /usr/local/lib/python3.8/dist-packages (from typepy[datetime]<2,>=1.2.0->pytablewriter>=0.10.2->PYEVALB) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.8/dist-packages (from python-dateutil<3.0.0,>=2.8.0->typepy[datetime]<2,>=1.2.0->pytablewriter>=0.10.2->PYEVALB) (1.15.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.8/dist-packages (from packaging->typepy[datetime]<2,>=1.2.0->pytablewriter>=0.10.2->PYEVALB) (3.0.9)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: apted in /usr/local/lib/python3.8/dist-packages (1.0.3)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: stanza in /usr/local/lib/python3.8/dist-packages (1.4.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.8/dist-packages (from stanza) (4.64.1)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.8/dist-packages (from stanza) (3.19.6)
# Requirement already satisfied: six in /usr/local/lib/python3.8/dist-packages (from stanza) (1.15.0)
# Requirement already satisfied: torch>=1.3.0 in /usr/local/lib/python3.8/dist-packages (from stanza) (1.13.0+cu116)
# Requirement already satisfied: requests in /usr/local/lib/python3.8/dist-packages (from stanza) (2.25.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.8/dist-packages (from stanza) (1.21.6)
# Requirement already satisfied: emoji in /usr/local/lib/python3.8/dist-packages (from stanza) (2.2.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.8/dist-packages (from torch>=1.3.0->stanza) (4.4.0)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests->stanza) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests->stanza) (2022.12.7)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests->stanza) (1.24.3)
# Requirement already satisfied: chardet<5,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests->stanza) (4.0.0)

# %% [markdown]
# ### Import

# %%
import StanfordDependencies
import spacy
from spacy import displacy
import statistics
from spacy import displacy
from spacy.tokens import Doc
from PYEVALB import parser
from PYEVALB.scorer import Scorer
from nltk.tree import Tree as Tree2
from apted import APTED, Config
import numpy as np
from pathlib import Path
import os

# %% [markdown]
# ### Load dir

# %%
# !git clone https://github.com/gabriele-dominici/L95_assignment.git
# Out:
# fatal: destination path 'L95_assignment' already exists and is not an empty directory.

# %% [markdown]
# ### Initialisation of some variables

# %%
# Object to translate constituency parser in dependency parser
sd = StanfordDependencies.get_instance(backend='subprocess', version='3.5.1')
# Object needed to visulise dependency trees
nlp = spacy.load("en_core_web_sm")
# Object to computer Parseval 
scorer = Scorer()

# %%
#@title Modify some class of APTED
from collections import deque
import logging
import re

from stanza.models.common import utils
from stanza.models.constituency.parse_tree import Tree

tqdm = utils.get_tqdm()

OPEN_PAREN = "("
CLOSE_PAREN = ")"

logger = logging.getLogger('stanza.constituency')

# A few specific exception types to clarify parsing errors
# They store the line number where the error occurred

class UnclosedTreeError(ValueError):
    """
    A tree looked like (Foo
    """
    def __init__(self, line_num):
        super().__init__("Found an unfinished tree (missing close brackets).  Tree started on line %d" % line_num)
        self.line_num = line_num

class ExtraCloseTreeError(ValueError):
    """
    A tree looked like (Foo))
    """
    def __init__(self, line_num):
        super().__init__("Found a broken tree (extra close brackets).  Tree started on line %d" % line_num)
        self.line_num = line_num

class UnlabeledTreeError(ValueError):
    """
    A tree had no label, such as ((Foo) (Bar))
    This does not actually happen at the root, btw, as ROOT is silently added
    """
    def __init__(self, line_num):
        super().__init__("Found a tree with no label on a node!  Line number %d" % line_num)
        self.line_num = line_num

class MixedTreeError(ValueError):
    """
    Leaf and constituent children are mixed in the same node
    """
    def __init__(self, line_num, child_label, children):
        super().__init__("Found a tree with both text children and bracketed children!  Line number {}  Child label {}  Children {}".format(line_num, child_label, children))
        self.line_num = line_num
        self.child_label = child_label
        self.children = children

def normalize(text):
    return text.replace("-LRB-", "(").replace("-RRB-", ")")

def read_single_tree(token_iterator, broken_ok):
    """
    Build a tree from the tokens in the token_iterator
    """
    # we were called here at a open paren, so start the stack of
    # children with one empty list already on it
    children_stack = deque()
    children_stack.append([])
    text_stack = deque()
    text_stack.append([])

    token = next(token_iterator, None)
    token_iterator.set_mark()
    while token is not None:
        if token == OPEN_PAREN:
            children_stack.append([])
            text_stack.append([])
        elif token == CLOSE_PAREN:
            text = text_stack.pop()
            children = children_stack.pop()
            if text:
                pieces = " ".join(text).split()
                if len(pieces) == 1:
                    child = Tree(pieces[0], children)
                else:
                    # the assumption here is that a language such as VI may
                    # have spaces in the words, but it still represents
                    # just one child
                    label = pieces[0]
                    child_label = " ".join(pieces[1:])
                    if children:
                        if broken_ok:
                            child = Tree(label, children + [Tree(normalize(child_label))])
                        else:
                            raise MixedTreeError(token_iterator.line_num, child_label, children)
                    else:
                        child = Tree(label, Tree(normalize(child_label)))
                if not children_stack:
                    return child
            else:
                if not children_stack:
                    return Tree("ROOT", children)
                elif broken_ok:
                    child = Tree(None, children)
                else:
                    raise UnlabeledTreeError(token_iterator.line_num)
            children_stack[-1].append(child)
        else:
            text_stack[-1].append(token)
        token = next(token_iterator, None)
    raise UnclosedTreeError(token_iterator.get_mark())

LINE_SPLIT_RE = re.compile(r"([()])")

class TokenIterator:
    """
    A specific iterator for reading trees from a tree file
    The idea is that this will keep track of which line
    we are processing, so that an error can be logged
    from the correct line
    """
    def __init__(self, text):
        self.lines = text.split("\n")
        self.num_lines = len(self.lines)
        self.line_num = -1
        if self.num_lines > 1000:
            self.line_iterator = iter(tqdm(self.lines))
        else:
            self.line_iterator = iter(self.lines)
        self.token_iterator = iter([])
        self.mark = None

    def set_mark(self):
        self.mark = self.line_num

    def get_mark(self):
        if self.mark is None:
            raise ValueError("No mark set!")
        return self.mark

    def __iter__(self):
        return self

    def __next__(self):
        n = next(self.token_iterator, None)
        while n is None:
            self.line_num = self.line_num + 1
            if self.line_num >= self.num_lines:
                next(self.line_iterator, "")
                raise StopIteration

            line = next(self.line_iterator, "").strip()
            if not line:
                continue

            pieces = LINE_SPLIT_RE.split(line)
            pieces = [x.strip() for x in pieces]
            pieces = [x for x in pieces if x]
            self.token_iterator = iter(pieces)
            n = next(self.token_iterator, None)

        return n

def read_trees(text, broken_ok=False):
    """
    Reads multiple trees from the text
    TODO: some of the error cases we hit can be recovered from
    """
    trees = []
    token_iterator = TokenIterator(text)
    token = next(token_iterator, None)
    while token:
        if token == OPEN_PAREN:
            next_tree = read_single_tree(token_iterator, broken_ok=broken_ok)
            if next_tree is None:
                raise ValueError("Tree reader somehow created a None tree!  Line number %d" % token_iterator.line_num)
            trees.append(next_tree)
            token = next(token_iterator, None)
        elif token == CLOSE_PAREN:
            raise ExtraCloseTreeError(token_iterator.line_num)
        else:
            raise ValueError("Tree document had text between trees!  Line number %d" % token_iterator.line_num)

    return trees

def read_tree_file(filename):
    """
    Read all of the trees in the given file
    """
    with open(filename) as fin:
        trees = read_trees(fin.read())
    return trees

def read_treebank(filename):
    """
    Read a treebank and alter the trees to be a simpler format for learning to parse
    """
    logger.info("Reading trees from %s", filename)
    trees = read_tree_file(filename)
    trees = [t.prune_none().simplify_labels() for t in trees]

    illegal_trees = [t for t in trees if len(t.children) > 1]
    if len(illegal_trees) > 0:
        raise ValueError("Found {} tree(s) which had non-unary transitions at the ROOT.  First illegal tree: {}".format(len(illegal_trees), illegal_trees[0]))

    return trees

# %% [markdown]
# ### Load and preprocessing gold standard

# %%
f = open("./L95_assignment/data/final_gold.txt", "r")
read = f.readlines()

# %%
# Preprocessing to store pos tags, costituency 
# and entire dependency parsing
count = 2
pos_tags = []
cp_gold = []
dp_gold = []
last = count
tmp_dep = ''
for row in read:
  if row == '\n':
    last = count
    count = (count + 1) % 3
  elif count == 0:
    pos_tags += [row]
    last = count
  elif count == 1:
    cp_gold += [row]
    last = count
  elif count == 2 and last == count:
    tmp_dep += [row]
    last = count
  elif count == 2:
    if tmp_dep != '':
      dp_gold += [tmp_dep]
    tmp_dep = [row]
    last = count
dp_gold += [tmp_dep]

# %%
# Preprocessing to store words and dependency trees
final_dp_gold = []
final_words_w_index = []
for s in dp_gold:
  tmp_words = []
  for el in s:
    tmp_el = el[1:-3].split('| ')
    k = len(tmp_el) - 1
    tmp_words += [tmp_el[k][1:]]
  final_words_w_index += [tmp_words]

for s, w in zip(dp_gold, final_words_w_index):
  tmp_dp = []
  for el in s:
    tmp_el = el[1:-3].split('| ')
    # relation, head, child
    k = len(tmp_el) - 2
    h = tmp_el[k][1:]
    if len(tmp_el) > 3:
      tmp_el = [tmp_el[0][1:]+':'+tmp_el[1][1:],
                w.index(h),
                int(tmp_el[3][1:].split(":")[1].split('_')[0])]
    elif len(tmp_el) == 2:
      tmp_el = [tmp_el[0][1:],
                None,
                int(tmp_el[1][1:].split(":")[1].split('_')[0])]
    else:
      tmp_el = [tmp_el[0][1:],
                w.index(h),
                int(tmp_el[2][1:].split(":")[1].split('_')[0])]
    tmp_dp += [tmp_el]
  
  tmp_dp.sort(key = lambda x: x[2])
  final_dp_gold += [tmp_dp]

for s in range(len(final_words_w_index)):
  for i in range(len(final_words_w_index[s])):
    final_words_w_index[s][i] = final_words_w_index[s][i].split(':')[0]


dp_gold_to_use = []
for i in final_dp_gold:
  dp_gold_to_use += [list(zip(*i))]

# %%
gold_pos_tag = []
words = []
for s in pos_tags:
  print(s)
  tmp = []
  tmp_word = {}
  for el in s[:-1].split(' '):
    tmp += [el[:-1].split('_')[-1]]
    tmp_word[el[:-1].split('_')[0][1:]] = ''.join(el[:-1].split('_')[0].split(':')[0].split('+'))[1:]
  gold_pos_tag += [tmp]
  words += [tmp_word]
# Out:
# |My:0_PRP$| |aunt:1_NN| |'s+:2_POS| |can:3_NN| |opener:4_NN| |can:5_MD| |open:6_VB| |a:7_DT| |drum:8_NN| |.:9_.|
#
# |The:0_DT| |old:1_JJ| |car:2_NN| |broke:3_VBD| |down:4_RP| |in:5_IN| |the:6_DT| |car:7_NN| |park:8_NN| |.:9_.|
#
# |At:0_RB| |least:1_RBS| |two:2_CD| |men:3_NNS| |broke:4_VBD| |in:5_RP| |and:6_CC| |stole:7_VBD| |my:8_PRP$| |TV:9_NN| |.:10_.|
#
# |Kim:0_NNP| |and:1_CC| |Sandy:2_NNP| |both:3_RB| |broke:4_VBD| |up:5_RP| |with:6_IN| |their:7_PRP$| |partner+s:8_NNS| |.:9_.|
#
# |The:0_DT| |horse:1_NN| |as:2_RB| |well:3_RB| |as:4_RB| |the:5_DT| |rabbit+s:6_NNS| |which:7_WDT| |we:8_PRP| |want+ed:9_VBD| |to:10_TO| |eat:11_VB| |has:12_VBZ| |escaped:13_VBN| |.:14_.|
#
# |It:0_PRP| |was:1_VBD| |my:2_PRP$| |aunt:3_NN| |'s+:4_POS| |car:5_NN| |which:6_WDT| |we:7_PRP| |sold:8_VBD| |at:9_IN| |auction:10_NN| |last:11_RB| |year:12_NN| |in:13_IN| |February:14_NNP| |.:15_.|
#
# |Natural:0_JJ| |disaster+s:1_NNS| |–:2_:| |storm+s:3_NNS| |,:4_,| |flood+ing:5_NN| |,:6_,| |hurricane+s:7_NNS| |–:8_:| |occur:9_VBP| |infrequently:10_RB| |but:11_CC| |cause:12_VBP| |devastation:13_NN| |that:14_WDT| |strain+s:15_VBZ| |resource+s:16_NNS| |to:17_IN| |break+ing:18_NN| |point:19_NN| |.:20_.|
#
# |Letter+s:0_NNS| |deliver+ed:1_VBN| |on:2_IN| |time:3_NN| |by:4_IN| |old:5_JJ| |-:6_HYPH| |fashion+ed:7_JJ| |means:8_NNS| |are:9_VBP| |increasingly:10_RB| |rare:11_JJ| |,:12_,| |so:13_RB| |it:14_PRP| |is:15_VBZ| |as:16_RB| |well:17_RB| |that:18_IN| |that:19_DT| |is:20_VBZ| |not+:21_RB| |the:22_DT| |only:23_JJ| |option:24_NN| |available:25_JJ| |.:26_.|
#
# |English:0_NNP| |also:1_RB| |has:2_VBZ| |many:3_JJ| |word+s:4_NNS| |of:5_IN| |more:6_JJR| |or:7_CC| |less:8_JJR| |unique:9_JJ| |function:10_NN| |,:11_,| |including:12_VBG| |interjection+s:13_NNS| |-LRB-:14_-LRB-| |oh:15_UH| |,:16_,| |ah:17_UH| |-RRB-:18_-RRB-| |,:19_,| |negative+s:20_NNS| |-LRB-:21_-LRB-| |no:22_RB| |,:23_,| |not+:24_RB| |-RRB-:25_-RRB-| |,:26_,| |politeness:27_NN| |marker+s:28_NNS| |-LRB-:29_-LRB-| |please:30_UH| |,:31_,| |thank:32_VB| |you:33_PRP| |-RRB-:34_-RRB-| |,:35_,| |and:36_CC| |the:37_DT| |existential:38_JJ| |':39_``| |there:40_RB| |':41_''| |-LRB-:42_-LRB-| |there:43_EX| |are:44_VBP| |horse+s:45_NNS| |but:46_CC| |not+:47_RB| |unicorn+s:48_NNS| |-RRB-:49_-RRB-| |among:50_IN| |other+s:51_NNS| |.:52_.|
#
# |The:0_DT| |Penn:1_NNP| |Treebank:2_NNP| |tagset:3_NN| |was:4_VBD| |cull+ed:5_VBN| |from:6_IN| |the:7_DT| |original:8_JJ| |87:9_CD| |-:10_HYPH| |tag:11_NN| |tagset:12_NN| |for:13_IN| |the:14_DT| |Brown:15_NNP| |Corpus:16_NNP| |.:17_.|
#
# |For:0_IN| |example:1_NN| |the:2_DT| |original:3_JJ| |Brown:4_NNP| |and:5_CC| |C5:6_NNP| |tagset+s:7_NNS| |include:8_VBP| |a:9_DT| |separate:10_JJ| |tag:11_NN| |for:12_IN| |each:13_DT| |of:14_IN| |the:15_DT| |different:16_JJ| |form+s:17_NNS| |of:18_IN| |the:19_DT| |verb+s:20_NNP| |do:21_VB| |-LRB-:22_-LRB-| |e.g.:23_RB| |C5:24_NNP| |tag:25_NN| |VDD:26_NN| |for:27_IN| |did:28_VBN| |and:29_CC| |VDG:30_NN| |tag:31_NN| |for:32_IN| |doing:33_VBG| |-RBR-:34_-RRB-| |,:35_,| |be:36_VB| |and:37_CC| |have:38_VB| |.:39_.|

# %%
# Final preprocessing for constituency trees
cp_gold_final = []
for index, s in enumerate(cp_gold):
  sentence = s[:-1]
  for w in words[index].items():
    sentence = sentence.replace(w[0], w[1], 1)
  cp_gold_final += [sentence]

# %% [markdown]
# ### Preprocessing and load of LAL parser tree

# %%
# Load of constituency trees
f = open("./L95_assignment/data/LAL_constituency.txt", "r")
cd_tree_p1 = f.readlines()

# %%
# Load of dependency heads
f = open("./L95_assignment/data/LAL_heads.txt", "r")
dep_heads = f.readlines()

# %%
# Preprocessing heads
new_dep_heads = []
for s in dep_heads:
  temp = s[1:-2].split(', ')
  dep_heads_s = []
  for el in temp:
    if int(el) == 0:
      dep_heads_s += [None]
    else:
      dep_heads_s += [int(el)-1]
  new_dep_heads += [dep_heads_s]

# %%
# Load of dependency relations
f = open("./L95_assignment/data/LAL_deps.txt", "r")
dep_labels = f.readlines()

# %%
# Preprocessing relations
new_dep_labels = []
for s in dep_labels:
  temp = s[1:-2].split(', ')
  dep_labels_s = []
  for el in temp:
    if el[1:-1] == 'root':
      dep_labels_s += ['ROOT']
    else:
      dep_labels_s += [el[1:-1]]
  new_dep_labels += [dep_labels_s]

# %%
# Load original sentences
f = open("./L95_assignment/data/AJ_input.txt", "r")
sentences = f.readlines()

# %%
# Sentences words
words_to_use = []
for s in sentences:
  words_to_use += [s[:-1].split(" ")]

# %% [markdown]
# ### Load and preprocessing of AJ constituency parsing

# %%
# Load of constituency parsing
f = open("./L95_assignment/data/AJ_constituency.txt", "r")
cd_tree_p2 = f.readlines()

# %%
# Converting constituency predictions in dependency trees
dp_tree_p2 = []
for i in cd_tree_p2:
  print(i)
  try:
    dp_tree_p2 += [sd.convert_tree(i)]
  except Exception as e:
    print('ERROR')
    print(e)
# Out:
# (S (NP (NP (PRP$ My) (NN aunt) (POS 's)) (MD can) (NN opener)) (VP (MD can) (VP (VB open) (NP (DT a) (NN drum)))) (. .))
#
# (S (NP (DT The) (JJ old) (NN car)) (VP (VBD broke) (PRT (RP down)) (PP (IN in) (NP (DT the) (NN car) (NN park)))) (. .))
#
# (S (NP (QP (RB At) (JJS least) (CD two)) (NNS men)) (VP (VP (VBD broke) (PRT (RP in))) (CC and) (VP (VBD stole) (NP (PRP$ my) (NN TV)))) (. .))
#
# (S (NP (NNP Kim) (CC and) (NNP Sandy)) (DT both) (VP (VBD broke) (PRT (RP up)) (PP (IN with) (NP (PRP$ their) (NNS partners)))) (. .))
#
# (S (NP (NP (DT The) (NN horse)) (CONJP (RB as) (RB well) (IN as)) (NP (NP (DT the) (NNS rabbits)) (SBAR (WHNP (WDT which)) (S (NP (PRP we)) (VP (VBD wanted) (S (VP (TO to) (VP (VB eat))))))))) (VP (VBZ has) (VP (VBN escaped))) (. .))
#
# (S (NP (PRP It)) (VP (VBD was) (NP (NP (NP (PRP$ my) (NN aunt) (POS 's)) (NN car)) (SBAR (WHNP (WDT which)) (S (NP (PRP we)) (VP (VBD sold) (PP (IN at) (NP (NN auction))) (NP (JJ last) (NN year)) (PP (IN in) (NP (NNP February)))))))) (. .))
#
# (S (NP (NP (JJ Natural) (NNS disasters)) (PRN (HYPN –) (NP (NNS storms) (, ,) (NN flooding) (, ,) (NNS hurricanes)) (HYPN –))) (VP (VP (VBP occur) (ADVP (RB infrequently))) (CC but) (VP (VB cause) (NP (NP (NN devastation)) (SBAR (WHNP (WDT that)) (S (VP (VBZ strains) (NP (NNS resources)) (PP (IN to) (NP (VBG breaking) (NN point))))))))) (. .))
#
# (S (S (NP (NP (NNS Letters)) (VP (VBD delivered) (PP (IN on) (NP (NN time))) (PP (IN by) (NP (JJ old) (HYPN -) (JJ fashioned) (NNS means))))) (VP (VBP are) (ADJP (RB increasingly) (JJ rare)))) (, ,) (IN so) (S (NP (NP (PRP it))) (VP (VBZ is) (ADVP (RB as) (RB well)) (SBAR (IN that) (S (NP (DT that)) (VP (VBZ is) (RB not) (NP (NP (DT the) (JJ only) (NN option)) (ADJP (JJ available)))))))) (. .))
#
# (S (NP (NNP English)) (ADVP (RB also)) (VP (VBZ has) (NP (NP (JJ many) (NNS words)) (PP (IN of) (NP (ADJP (ADVP (JJR more) (CC or) (RBR less)) (JJ unique)) (NN function))) (, ,) (PP (VBG including) (NP (NP (NP (NNS interjections)) (PRN (-LRB- -LRB-) (INTJ (UH oh) (, ,) (UH ah)) (-RRB- -RRB-))) (, ,) (NP (NP (NNS negatives)) (PRN (-LRB- -LRB-) (INTJ (UH no) (, ,) (RB not)) (-RRB- -RRB-))) (, ,) (NP (NP (NN politeness) (NNS markers)) (PRN (-LRB- -LRB-) (NP (INTJ (UH please)) (, ,) (VBP thank) (PRP you)) (-RRB- -RRB-))) (, ,) (CC and) (NP (NP (NP (DT the) (JJ existential) (`` ') (EX there) ('' ')) (PRN (-LRB- -LRB-) (S (NP (EX there)) (VP (VBP are) (NP (NP (NNS horses)) (CC but) (RB not) (NP (NNS unicorns))))) (-RRB- -RRB-))) (PP (IN among) (NP (NNS others)))))))) (. .))
#
# (S (NP (DT The) (NNP Penn) (NNP Treebank) (NN tagset)) (VP (VBD was) (VP (VBN culled) (PP (IN from) (NP (NP (DT the) (JJ original) (CD 87) (HYPN -) (NN tag) (NN tagset)) (PP (IN for) (NP (DT the) (NNP Brown) (NNP Corpus))))))) (. .))
#
# (S (PP (IN For) (NP (NN example))) (NP (DT the) (JJ original) (NNP Brown) (CC and) (NNP C5) (NNS tagsets)) (VP (VBP include) (NP (NP (DT a) (JJ separate) (NN tag)) (PP (IN for) (NP (NP (DT each)) (PP (IN of) (NP (NP (DT the) (JJ different) (NNS forms)) (PP (IN of) (NP (DT the) (NNS verbs) (NP (VP (VBP do)) (PRN (-LRB- -LRB-) (RB e.g.) (NP (NP (NP (NNP C5) (NN tag) (NN VDD)) (PP (IN for) (S (VP (VBD did))))) (CC and) (NP (NP (NNP VDG) (NN tag)) (PP (IN for) (NP (VBG doing))))) (-RRB- -RRB-))) (, ,) (VB be) (CC and) (VB have))))))))) (. .))

# %% [markdown]
# ### Comparing constituency parsing

# %%
# Custom Config to use with Apted
class CustomConfig(Config):
  def rename(self, node1, node2):
      """Compares attribute .value of trees"""
      return int(node1.label != node2.label)

  def children(self, node):
      """Get left and right children of binary tree"""
      return getattr(node, 'children', [])

# %%
# func to print tree in a format usable in Latex
def tranlsate_tree_latex(tree):
  tree = tree.replace('(', '[')
  tree = tree.replace(')', ']')
  return tree

# %%
# Initialisation of some variables
ed_1g = []
ed_2g = []
p_1g = []
p_2g = []
r_1g = []
r_2g = []
f1_1g = []
f1_2g = []
cb_1g = []
cb_2g = []
pos_1g = []
pos_2g = []
# Comparing trees
for i, j, g in zip(cd_tree_p1, cd_tree_p2, cp_gold_final):

  # Create trees usable by different metrics 
  print('GOLD')
  # Tree for Latex
  print(tranlsate_tree_latex(g))
  # Tree visualisation
  treeg = Tree2.fromstring(g)
  treeg.pretty_print()
  # Tree for APTED
  token_iterator = TokenIterator(g+')')
  treeg_t = read_single_tree(token_iterator, False)

  print('LAL Parser')
  print(tranlsate_tree_latex(i))
  tree1 = Tree2.fromstring(i)
  token_iterator = TokenIterator(i+')')
  tree1_t = read_single_tree(token_iterator, False)
  tree1.pretty_print()

  print('AJ Graph Parser')
  print(tranlsate_tree_latex(j))
  tree2 = Tree2.fromstring(j)
  token_iterator = TokenIterator(j+')')
  tree2_t = read_single_tree(token_iterator, False)
  tree2.pretty_print()

  # Trees for PARSEVAL  
  gold_tree = parser.create_from_bracket_string(g)
  LAL_tree = parser.create_from_bracket_string(i)
  AJ_tree = parser.create_from_bracket_string(j)
  
  # GOLD vs LAL
  # PARSEVAL scores, Cross bracketing, POS accuracy
  result1 = scorer.score_trees(gold_tree, LAL_tree)
  # Edit Distance
  apted = APTED(tree1_t, treeg_t, CustomConfig())
  print('Gold vs LAL Parser')
  print(f"Edit distance :{apted.compute_edit_distance()}")

  F1Score = (2*result1.recall*result1.prec)/(result1.recall+result1.prec)

  # Metrics
  print('Recall =' + str(result1.recall))
  print('Precision =' + str(result1.prec))
  print('F1-Score =' + str(F1Score))
  # Store metrics
  r_1g += [result1.recall]
  p_1g += [result1.prec]
  f1_1g += [F1Score]
  ed_1g += [apted.compute_edit_distance()]
  cb_1g += [result1.cross_brackets]
  pos_1g += [result1.tag_accracy]
  print(result1)

  # GOLD vs AJ

  result2 = scorer.score_trees(gold_tree, AJ_tree)

  apted = APTED(tree2_t, treeg_t, CustomConfig())
  print('Gold vs AJ Graph Parser')
  print(f"Edit distance :{apted.compute_edit_distance()}")

  F1Score = (2*result2.recall*result2.prec)/(result2.recall+result2.prec)
  
  print('Recall =' + str(result2.recall))
  print('Precision =' + str(result2.prec))
  print('F1-Score =' + str(F1Score))
  r_2g += [result2.recall]
  p_2g += [result2.prec]
  f1_2g += [F1Score]
  ed_2g += [apted.compute_edit_distance()]
  cb_2g += [result2.cross_brackets]
  pos_2g += [result2.tag_accracy]
  print(result2)

  # Comparison of the two parsers
  print('LAL Parser vs AJ Graph Parser')
  print(scorer.score_trees(LAL_tree, AJ_tree))
  print('-----------------')
# Out:
# GOLD
# [S [NP [PRP$ My] [NP [NN aunt] [NP [POS 's] [NP [NN can] [NN opener]]]]] [VP [MD can] [VP [VB open] [NP [DT a] [NN drum]]]] [. .]]
#                             S
#             ________________|_______________________________
#            NP                              |                |
#   _________|___                            |                |
#  |             NP                          VP               |
#  |     ________|___                ________|___             |
#  |    |            NP             |            VP           |
#  |    |     _______|___           |    ________|___         |
#  |    |    |           NP         |   |            NP       |
#  |    |    |        ___|____      |   |         ___|___     |
# PRP$  NN  POS      NN       NN    MD  VB       DT      NN   .
#  |    |    |       |        |     |   |        |       |    |
#  My  aunt  's     can     opener can open      a      drum  .
#
# LAL Parser
# [S [NP [NP [PRP$ My] [NN aunt] [POS 's]] [MD can] [VB opener]] [VP [MD can] [VP [VB open] [NP [DT a] [NN drum]]]] [. .]]
#
#                     S
#             ________|_______________________________
#            |                       VP               |
#            |               ________|___             |
#            NP             |            VP           |
#        ____|________      |    ________|___         |
#       NP       |    |     |   |            NP       |
#   ____|____    |    |     |   |         ___|___     |
# PRP$  NN  POS  MD   VB    MD  VB       DT      NN   .
#  |    |    |   |    |     |   |        |       |    |
#  My  aunt  's can opener can open      a      drum  .
#
# AJ Graph Parser
# [S [NP [NP [PRP$ My] [NN aunt] [POS 's]] [MD can] [NN opener]] [VP [MD can] [VP [VB open] [NP [DT a] [NN drum]]]] [. .]]
#
#                     S
#             ________|_______________________________
#            |                       VP               |
#            |               ________|___             |
#            NP             |            VP           |
#        ____|________      |    ________|___         |
#       NP       |    |     |   |            NP       |
#   ____|____    |    |     |   |         ___|___     |
# PRP$  NN  POS  MD   NN    MD  VB       DT      NN   .
#  |    |    |   |    |     |   |        |       |    |
#  My  aunt  's can opener can open      a      drum  .
#
# Gold vs LAL Parser
# Edit distance :6
# Recall =0.625
# Precision =0.8333333333333334
# F1-Score =0.7142857142857143
# ID:  0 length: 10 state:  0 recall:62.50 prec:83.33 matched_brackets:  5 gold_brackets:  8 test_brackets:  6 cross_brackets:  1 words: 10 correct_tags:  8 tag_accracy:80.00
# Gold vs AJ Graph Parser
# Edit distance :5
# Recall =0.625
# Precision =0.8333333333333334
# F1-Score =0.7142857142857143
# ID:  0 length: 10 state:  0 recall:62.50 prec:83.33 matched_brackets:  5 gold_brackets:  8 test_brackets:  6 cross_brackets:  1 words: 10 correct_tags:  9 tag_accracy:90.00
# LAL Parser vs AJ Graph Parser
# ID:  0 length: 10 state:  0 recall:100.00 prec:100.00 matched_brackets:  6 gold_brackets:  6 test_brackets:  6 cross_brackets:  0 words: 10 correct_tags:  9 tag_accracy:90.00
# -----------------
# GOLD
# [S [NP [DT The] [NP [ADJP [JJ old]] [NN car]]]   [VP [V [VBD broke] [RP down]]    [PP [IN in] [NP [DT the] [NP [NN car] [NN park]]]]]  [. .]]
#                             S
#       ______________________|_____________________________
#      |                           VP                       |
#      |                   ________|_______                 |
#      NP                 |                PP               |
#   ___|____              |         _______|___             |
#  |        NP            |        |           NP           |
#  |    ____|___          |        |    _______|___         |
#  |  ADJP      |         V        |   |           NP       |
#  |   |        |     ____|___     |   |        ___|___     |
#  DT  JJ       NN  VBD       RP   IN  DT      NN      NN   .
#  |   |        |    |        |    |   |       |       |    |
# The old      car broke     down  in the     car     park  .
#
# LAL Parser
# [S [NP [DT The] [JJ old] [NN car]] [VP [VBD broke] [PRT [RB down]] [PP [IN in] [NP [DT the] [NN car] [NN park]]]] [. .]]
#
#                    S
#       _____________|_________________________
#      |                  VP                   |
#      |         _________|_______             |
#      |        |    |            PP           |
#      |        |    |     _______|___         |
#      NP       |   PRT   |           NP       |
#   ___|___     |    |    |    _______|___     |
#  DT  JJ  NN  VBD   RB   IN  DT      NN  NN   .
#  |   |   |    |    |    |   |       |   |    |
# The old car broke down  in the     car park  .
#
# AJ Graph Parser
# [S [NP [DT The] [JJ old] [NN car]] [VP [VBD broke] [PRT [RP down]] [PP [IN in] [NP [DT the] [NN car] [NN park]]]] [. .]]
#
#                    S
#       _____________|_________________________
#      |                  VP                   |
#      |         _________|_______             |
#      |        |    |            PP           |
#      |        |    |     _______|___         |
#      NP       |   PRT   |           NP       |
#   ___|___     |    |    |    _______|___     |
#  DT  JJ  NN  VBD   RP   IN  DT      NN  NN   .
#  |   |   |    |    |    |   |       |   |    |
# The old car broke down  in the     car park  .
#
# Gold vs LAL Parser
# Edit distance :6
# Recall =0.5555555555555556
# Precision =0.8333333333333334
# F1-Score =0.6666666666666667
# ID:  0 length: 10 state:  0 recall:55.56 prec:83.33 matched_brackets:  5 gold_brackets:  9 test_brackets:  6 cross_brackets:  0 words: 10 correct_tags:  9 tag_accracy:90.00
# Gold vs AJ Graph Parser
# Edit distance :5
# Recall =0.5555555555555556
# Precision =0.8333333333333334
# F1-Score =0.6666666666666667
# ID:  0 length: 10 state:  0 recall:55.56 prec:83.33 matched_brackets:  5 gold_brackets:  9 test_brackets:  6 cross_brackets:  0 words: 10 correct_tags: 10 tag_accracy:100.00
# LAL Parser vs AJ Graph Parser
# ID:  0 length: 10 state:  0 recall:100.00 prec:100.00 matched_brackets:  6 gold_brackets:  6 test_brackets:  6 cross_brackets:  0 words: 10 correct_tags:  9 tag_accracy:90.00
# -----------------
# GOLD
# [S [NP [ADVP [RB At]   [ADVP [RBS least] [CD two]]] [NNS men]]     [VP [VP [V [VBD broke] [RP in]]]      [CONJP [CC and]       [VP [VBD stole] [NP [PRP$ my] [NN TV]]]]] [. .]]
#                                   S
#             ______________________|________________________________
#            |                          VP                           |
#            |                   _______|__________                  |
#            NP                 |                CONJP               |
#        ____|________          |        __________|____             |
#      ADVP           |         VP      |               VP           |
#   ____|____         |         |       |     __________|____        |
#  |        ADVP      |         V       |    |               NP      |
#  |     ____|____    |     ____|___    |    |           ____|___    |
#  RB  RBS        CD NNS  VBD       RP  CC  VBD        PRP$      NN  .
#  |    |         |   |    |        |   |    |          |        |   |
#  At least      two men broke      in and stole        my       TV  .
#
# LAL Parser
# [S [NP [QP [IN At] [JJS least] [CD two]] [NNS men]] [VP [VP [VBD broke] [PRT [IN in]]] [CC and] [VP [VB stole] [NP [PRP$ my] [NN TV]]]] [. .]]
#
#                                  S
#             _____________________|__________________________
#            |                         VP                     |
#            |                  _______|_________             |
#            NP                VP      |         VP           |
#        ____|_______      ____|___    |     ____|____        |
#       QP           |    |       PRT  |    |         NP      |
#   ____|________    |    |        |   |    |     ____|___    |
#  IN  JJS       CD NNS  VBD       IN  CC   VB  PRP$      NN  .
#  |    |        |   |    |        |   |    |    |        |   |
#  At least     two men broke      in and stole  my       TV  .
#
# AJ Graph Parser
# [S [NP [QP [RB At] [JJS least] [CD two]] [NNS men]] [VP [VP [VBD broke] [PRT [RP in]]] [CC and] [VP [VBD stole] [NP [PRP$ my] [NN TV]]]] [. .]]
#
#                                  S
#             _____________________|__________________________
#            |                         VP                     |
#            |                  _______|_________             |
#            NP                VP      |         VP           |
#        ____|_______      ____|___    |     ____|____        |
#       QP           |    |       PRT  |    |         NP      |
#   ____|________    |    |        |   |    |     ____|___    |
#  RB  JJS       CD NNS  VBD       RP  CC  VBD  PRP$      NN  .
#  |    |        |   |    |        |   |    |    |        |   |
#  At least     two men broke      in and stole  my       TV  .
#
# Gold vs LAL Parser
# Edit distance :9
# Recall =0.6
# Precision =0.75
# F1-Score =0.6666666666666665
# ID:  0 length: 11 state:  0 recall:60.00 prec:75.00 matched_brackets:  6 gold_brackets: 10 test_brackets:  8 cross_brackets:  0 words: 11 correct_tags:  7 tag_accracy:63.64
# Gold vs AJ Graph Parser
# Edit distance :6
# Recall =0.6
# Precision =0.75
# F1-Score =0.6666666666666665
# ID:  0 length: 11 state:  0 recall:60.00 prec:75.00 matched_brackets:  6 gold_brackets: 10 test_brackets:  8 cross_brackets:  0 words: 11 correct_tags: 10 tag_accracy:90.91
# LAL Parser vs AJ Graph Parser
# ID:  0 length: 11 state:  0 recall:100.00 prec:100.00 matched_brackets:  8 gold_brackets:  8 test_brackets:  8 cross_brackets:  0 words: 11 correct_tags:  8 tag_accracy:72.73
# -----------------
# GOLD
# [S [NP [NP [NNP Kim]] [CONJP [CC and] [NP [NNP Sandy]]]] [VP [ADVP [RB both]]   [VP [V [VBD broke] [RP up]]    [PP [IN with] [NP [PRP$ their] [NNS partners]]]]]  [. .]]
#                            S
#       _____________________|____________________________________
#      |                              VP                          |
#      |                ______________|___                        |
#      NP              |                  VP                      |
#   ___|____           |           _______|_____                  |
#  |      CONJP        |          |             PP                |
#  |    ____|_____     |          |        _____|____             |
#  NP  |          NP  ADVP        V       |          NP           |
#  |   |          |    |      ____|___    |      ____|_____       |
# NNP  CC        NNP   RB   VBD       RP  IN   PRP$       NNS     .
#  |   |          |    |     |        |   |     |          |      |
# Kim and       Sandy both broke      up with their     partners  .
#
# LAL Parser
# [S [NP [NNP Kim] [CC and] [NNP Sandy]] [DT both] [VP [VBD broke] [PRT [RP up]] [PP [IN with] [NP [PRP$ their] [NNS partners]]]] [. .]]
#
#                      S
#       _______________|________________________________
#      |         |              VP                      |
#      |         |      ________|_____                  |
#      |         |     |    |         PP                |
#      |         |     |    |    _____|____             |
#      NP        |     |   PRT  |          NP           |
#   ___|____     |     |    |   |      ____|_____       |
# NNP  CC  NNP   DT   VBD   RP  IN   PRP$       NNS     .
#  |   |    |    |     |    |   |     |          |      |
# Kim and Sandy both broke  up with their     partners  .
#
# AJ Graph Parser
# [S [NP [NNP Kim] [CC and] [NNP Sandy]] [DT both] [VP [VBD broke] [PRT [RP up]] [PP [IN with] [NP [PRP$ their] [NNS partners]]]] [. .]]
#
#                      S
#       _______________|________________________________
#      |         |              VP                      |
#      |         |      ________|_____                  |
#      |         |     |    |         PP                |
#      |         |     |    |    _____|____             |
#      NP        |     |   PRT  |          NP           |
#   ___|____     |     |    |   |      ____|_____       |
# NNP  CC  NNP   DT   VBD   RP  IN   PRP$       NNS     .
#  |   |    |    |     |    |   |     |          |      |
# Kim and Sandy both broke  up with their     partners  .
#
# Gold vs LAL Parser
# Edit distance :8
# Recall =0.45454545454545453
# Precision =0.8333333333333334
# F1-Score =0.5882352941176471
# ID:  0 length: 10 state:  0 recall:45.45 prec:83.33 matched_brackets:  5 gold_brackets: 11 test_brackets:  6 cross_brackets:  0 words: 10 correct_tags:  9 tag_accracy:90.00
# Gold vs AJ Graph Parser
# Edit distance :8
# Recall =0.45454545454545453
# Precision =0.8333333333333334
# F1-Score =0.5882352941176471
# ID:  0 length: 10 state:  0 recall:45.45 prec:83.33 matched_brackets:  5 gold_brackets: 11 test_brackets:  6 cross_brackets:  0 words: 10 correct_tags:  9 tag_accracy:90.00
# LAL Parser vs AJ Graph Parser
# ID:  0 length: 10 state:  0 recall:100.00 prec:100.00 matched_brackets:  6 gold_brackets:  6 test_brackets:  6 cross_brackets:  0 words: 10 correct_tags: 10 tag_accracy:100.00
# -----------------
# GOLD
# [S   [NP [NP [DT The] [NN horse]]    [CONJP [ADVP [RB as] [ADVP [RB well]] [ADVP [RB as]]]       [NP [NP [DT the] [NNS rabbits]]        [S [WDT which]         [S [PRP we]          [VP [VBD wanted] [VP [TO to] [VB eat]]]]]]]]   [VP [VBZ has] [VP [VBN escaped]]]  [. .]]
#                                               S
#                               ________________|_______________________________________________
#                              NP                                                   |           |
#       _______________________|_________                                           |           |
#      |                               CONJP                                        |           |
#      |              ___________________|___________                               |           |
#      |             |                               NP                             |           |
#      |             |              _________________|____                          |           |
#      |             |             |                      S                         |           |
#      |             |             |             _________|_____                    |           |
#      |             |             |            |               S                   |           |
#      |             |             |            |     __________|___                |           |
#      |            ADVP           |            |    |              VP              VP          |
#      |          ___|____         |            |    |     _________|___         ___|_____      |
#      NP        |  ADVP ADVP      NP           |    |    |             VP      |         VP    |
#   ___|____     |   |    |     ___|_____       |    |    |          ___|___    |         |     |
#  DT       NN   RB  RB   RB   DT       NNS    WDT  PRP  VBD        TO      VB VBZ       VBN    .
#  |        |    |   |    |    |         |      |    |    |         |       |   |         |     |
# The     horse  as well  as  the     rabbits which  we wanted      to     eat has     escaped  .
#
# LAL Parser
# [S [NP [NP [DT The] [NN horse]] [CONJP [RB as] [RB well] [IN as]] [NP [NP [DT the] [NNS rabbits]] [SBAR [WHNP [WDT which]] [S [NP [PRP we]] [VP [VBD wanted] [S [VP [TO to] [VP [VB eat]]]]]]]]] [VP [VBZ has] [VP [VBN escaped]]] [. .]]
#
#                                               S
#                               ________________|_______________________________________________
#                              NP                                                   |           |
#       _______________________|_____________________                               |           |
#      |              |                              NP                             |           |
#      |              |             _________________|____                          |           |
#      |              |            |                     SBAR                       |           |
#      |              |            |             _________|_____                    |           |
#      |              |            |            |               S                   |           |
#      |              |            |            |     __________|___                |           |
#      |              |            |            |    |              VP              |           |
#      |              |            |            |    |     _________|___            |           |
#      |              |            |            |    |    |             S           |           |
#      |              |            |            |    |    |             |           |           |
#      |              |            |            |    |    |             VP          VP          |
#      |              |            |            |    |    |          ___|___     ___|_____      |
#      NP           CONJP          NP          WHNP  NP   |         |       VP  |         VP    |
#   ___|____      ____|____     ___|_____       |    |    |         |       |   |         |     |
#  DT       NN   RB   RB   IN  DT       NNS    WDT  PRP  VBD        TO      VB VBZ       VBN    .
#  |        |    |    |    |   |         |      |    |    |         |       |   |         |     |
# The     horse  as  well  as the     rabbits which  we wanted      to     eat has     escaped  .
#
# AJ Graph Parser
# [S [NP [NP [DT The] [NN horse]] [CONJP [RB as] [RB well] [IN as]] [NP [NP [DT the] [NNS rabbits]] [SBAR [WHNP [WDT which]] [S [NP [PRP we]] [VP [VBD wanted] [S [VP [TO to] [VP [VB eat]]]]]]]]] [VP [VBZ has] [VP [VBN escaped]]] [. .]]
#
#                                               S
#                               ________________|_______________________________________________
#                              NP                                                   |           |
#       _______________________|_____________________                               |           |
#      |              |                              NP                             |           |
#      |              |             _________________|____                          |           |
#      |              |            |                     SBAR                       |           |
#      |              |            |             _________|_____                    |           |
#      |              |            |            |               S                   |           |
#      |              |            |            |     __________|___                |           |
#      |              |            |            |    |              VP              |           |
#      |              |            |            |    |     _________|___            |           |
#      |              |            |            |    |    |             S           |           |
#      |              |            |            |    |    |             |           |           |
#      |              |            |            |    |    |             VP          VP          |
#      |              |            |            |    |    |          ___|___     ___|_____      |
#      NP           CONJP          NP          WHNP  NP   |         |       VP  |         VP    |
#   ___|____      ____|____     ___|_____       |    |    |         |       |   |         |     |
#  DT       NN   RB   RB   IN  DT       NNS    WDT  PRP  VBD        TO      VB VBZ       VBN    .
#  |        |    |    |    |   |         |      |    |    |         |       |   |         |     |
# The     horse  as  well  as the     rabbits which  we wanted      to     eat has     escaped  .
#
# Gold vs LAL Parser
# Edit distance :10
# Recall =0.6666666666666666
# Precision =0.625
# F1-Score =0.6451612903225806
# ID:  0 length: 15 state:  0 recall:66.67 prec:62.50 matched_brackets: 10 gold_brackets: 15 test_brackets: 16 cross_brackets:  0 words: 15 correct_tags: 14 tag_accracy:93.33
# Gold vs AJ Graph Parser
# Edit distance :10
# Recall =0.6666666666666666
# Precision =0.625
# F1-Score =0.6451612903225806
# ID:  0 length: 15 state:  0 recall:66.67 prec:62.50 matched_brackets: 10 gold_brackets: 15 test_brackets: 16 cross_brackets:  0 words: 15 correct_tags: 14 tag_accracy:93.33
# LAL Parser vs AJ Graph Parser
# ID:  0 length: 15 state:  0 recall:100.00 prec:100.00 matched_brackets: 16 gold_brackets: 16 test_brackets: 16 cross_brackets:  0 words: 15 correct_tags: 15 tag_accracy:100.00
# -----------------
# GOLD
# [S [NP [PRP It]]   [VP [VBD was]    [NP [NP [PRP$ my] [NP [NN aunt] [NP [POS 's] [NN car]]]]     [S [WDT which]      [S [NP [PRP we]]       [VP [VP [VP [VBD sold] [PP [IN at] [NP [NN auction]]]]        [ADVP [RB last] [NP [NN year]]]]         [PP [IN in] [NP [NNP February]]]]]]]] [. .]]
#                                          S
#   _______________________________________|________________________________________________________
#  |            VP                                                                                  |
#  |    ________|________________                                                                   |
#  |   |                         NP                                                                 |
#  |   |              ___________|_____________                                                     |
#  |   |             |                         S                                                    |
#  |   |             |                 ________|______________                                      |
#  |   |             |                |                       S                                     |
#  |   |             |                |     __________________|_____                                |
#  |   |             |                |    |                        VP                              |
#  |   |             |                |    |                   _____|__________________             |
#  |   |             |                |    |                  VP                       |            |
#  |   |             |                |    |         _________|__________              |            |
#  |   |             NP               |    |        VP                   |             |            |
#  |   |    _________|___             |    |    ____|___                 |             |            |
#  |   |   |             NP           |    |   |        PP              ADVP           PP           |
#  |   |   |     ________|___         |    |   |     ___|_____       ____|____      ___|_____       |
#  NP  |   |    |            NP       |    NP  |    |         NP    |         NP   |         NP     |
#  |   |   |    |         ___|___     |    |   |    |         |     |         |    |         |      |
# PRP VBD PRP$  NN      POS      NN  WDT  PRP VBD   IN        NN    RB        NN   IN       NNP     .
#  |   |   |    |        |       |    |    |   |    |         |     |         |    |         |      |
#  It was  my  aunt      's     car which  we sold  at     auction last      year  in     February  .
#
# LAL Parser
# [S [NP [PRP It]] [VP [VBD was] [NP [NP [NP [PRP$ my] [NN aunt] [POS 's]] [NN car]] [SBAR [WHNP [WDT which]] [S [NP [PRP we]] [VP [VBD sold] [PP [IN at] [NP [NN auction]]] [NP [JJ last] [NN year]] [PP [IN in] [NP [NNP February]]]]]]]] [. .]]
#
#                                      S
#   ___________________________________|_______________________________________________________
#  |            VP                                                                             |
#  |    ________|____________                                                                  |
#  |   |                     NP                                                                |
#  |   |              _______|_____________                                                    |
#  |   |             |                    SBAR                                                 |
#  |   |             |             ________|______________                                     |
#  |   |             |            |                       S                                    |
#  |   |             |            |     __________________|_____                               |
#  |   |             |            |    |                        VP                             |
#  |   |             |            |    |    ____________________|_________________             |
#  |   |             NP           |    |   |        PP               |            PP           |
#  |   |         ____|_______     |    |   |     ___|_____           |         ___|_____       |
#  NP  |        NP           |   WHNP  NP  |    |         NP         NP       |         NP     |
#  |   |    ____|________    |    |    |   |    |         |      ____|___     |         |      |
# PRP VBD PRP$  NN      POS  NN  WDT  PRP VBD   IN        NN    JJ       NN   IN       NNP     .
#  |   |   |    |        |   |    |    |   |    |         |     |        |    |         |      |
#  It was  my  aunt      's car which  we sold  at     auction last     year  in     February  .
#
# AJ Graph Parser
# [S [NP [PRP It]] [VP [VBD was] [NP [NP [NP [PRP$ my] [NN aunt] [POS 's]] [NN car]] [SBAR [WHNP [WDT which]] [S [NP [PRP we]] [VP [VBD sold] [PP [IN at] [NP [NN auction]]] [NP [JJ last] [NN year]] [PP [IN in] [NP [NNP February]]]]]]]] [. .]]
#
#                                      S
#   ___________________________________|_______________________________________________________
#  |            VP                                                                             |
#  |    ________|____________                                                                  |
#  |   |                     NP                                                                |
#  |   |              _______|_____________                                                    |
#  |   |             |                    SBAR                                                 |
#  |   |             |             ________|______________                                     |
#  |   |             |            |                       S                                    |
#  |   |             |            |     __________________|_____                               |
#  |   |             |            |    |                        VP                             |
#  |   |             |            |    |    ____________________|_________________             |
#  |   |             NP           |    |   |        PP               |            PP           |
#  |   |         ____|_______     |    |   |     ___|_____           |         ___|_____       |
#  NP  |        NP           |   WHNP  NP  |    |         NP         NP       |         NP     |
#  |   |    ____|________    |    |    |   |    |         |      ____|___     |         |      |
# PRP VBD PRP$  NN      POS  NN  WDT  PRP VBD   IN        NN    JJ       NN   IN       NNP     .
#  |   |   |    |        |   |    |    |   |    |         |     |        |    |         |      |
#  It was  my  aunt      's car which  we sold  at     auction last     year  in     February  .
#
# Gold vs LAL Parser
# Edit distance :10
# Recall =0.631578947368421
# Precision =0.75
# F1-Score =0.6857142857142857
# ID:  0 length: 16 state:  0 recall:63.16 prec:75.00 matched_brackets: 12 gold_brackets: 19 test_brackets: 16 cross_brackets:  1 words: 16 correct_tags: 15 tag_accracy:93.75
# Gold vs AJ Graph Parser
# Edit distance :10
# Recall =0.631578947368421
# Precision =0.75
# F1-Score =0.6857142857142857
# ID:  0 length: 16 state:  0 recall:63.16 prec:75.00 matched_brackets: 12 gold_brackets: 19 test_brackets: 16 cross_brackets:  1 words: 16 correct_tags: 15 tag_accracy:93.75
# LAL Parser vs AJ Graph Parser
# ID:  0 length: 16 state:  0 recall:100.00 prec:100.00 matched_brackets: 16 gold_brackets: 16 test_brackets: 16 cross_brackets:  0 words: 16 correct_tags: 16 tag_accracy:100.00
# -----------------
# GOLD
# [S [NP [NP [ADJP [JJ Natural]] [NNS disasters]] [PRN [PRN [: –] [NP [NP [NP [NNS storms]] [LST [, ,] [NP [NN flooding]]]] [LST [, ,]     [NP [NNS hurricanes]]]]] [: –]]] [VP [VP [VP [VBP occur]] [ADVP [RB infrequently]]]  [CONJP [CC but] [VP [VBP cause] [NP [NN devastation] [S [WDT that]   [VP [VP [VBZ strains]    [NP [NNS resources]]]     [PP [IN to] [NP [NN breaking] [NN point]]]]]]]]]  [. .]]
#                                                                                         S
#                                    _____________________________________________________|________________________________________________________________________________
#                                   |                                                     VP                                                                               |
#                                   |                                              _______|_____________                                                                   |
#                                   NP                                            |                   CONJP                                                                |
#           ________________________|_________                                    |                 ____|________                                                          |
#          |                                 PRN                                  |                |             VP                                                        |
#          |                         _________|_________________________          |                |     ________|_______                                                  |
#          |                       PRN                                  |         |                |    |                NP                                                |
#          |              __________|_________                          |         |                |    |         _______|___________________                              |
#          |             |                    NP                        |         |                |    |        |                           S                             |
#          |             |           _________|__________               |         |                |    |        |        ___________________|______                       |
#          |             |          NP                   |              |         |                |    |        |       |                          VP                     |
#          |             |     _____|___                 |              |         |                |    |        |       |             _____________|_____                 |
#          NP            |    |        LST              LST             |         VP               |    |        |       |            VP                  PP               |
#     _____|______       |    |      ___|_____        ___|______        |     ____|_______         |    |        |       |       _____|______        _____|______          |
#   ADJP          |      |    NP    |         NP     |          NP      |    VP          ADVP      |    |        |       |      |            NP     |            NP        |
#    |            |      |    |     |         |      |          |       |    |            |        |    |        |       |      |            |      |      ______|____     |
#    JJ          NNS     :   NNS    ,         NN     ,         NNS      :   VBP           RB       CC  VBP       NN     WDT    VBZ          NNS     IN    NN          NN   .
#    |            |      |    |     |         |      |          |       |    |            |        |    |        |       |      |            |      |     |           |    |
# Natural     disasters  –  storms  ,      flooding  ,      hurricanes  –  occur     infrequently but cause devastation that strains     resources  to breaking     point  .
#
# LAL Parser
# [S [NP [NP [JJ Natural] [NNS disasters]] [PRN [VBP –] [NP [NNS storms] [, ,] [NN flooding] [, ,] [NNS hurricanes]] [VBP –]]] [VP [VP [VBP occur] [ADVP [RB infrequently]]] [CC but] [VP [VB cause] [NP [NP [NN devastation]] [SBAR [WHNP [IN that]] [S [VP [VBZ strains] [NP [NNS resources]] [PP [TO to] [NP [VBG breaking] [NN point]]]]]]]]] [. .]]
#
#                                                                                 S
#                                    _____________________________________________|____________________________________________________________________________
#                                   |                                                      VP                                                                  |
#                                   |                                      ________________|_____________                                                      |
#                                   |                                     |                |             VP                                                    |
#                                   |                                     |                |     ________|_______                                              |
#                                   |                                     |                |    |                NP                                            |
#                                   |                                     |                |    |         _______|_______________                              |
#                                   |                                     |                |    |        |                      SBAR                           |
#                                   |                                     |                |    |        |        _______________|______                       |
#                                   |                                     |                |    |        |       |                      S                      |
#                                   |                                     |                |    |        |       |                      |                      |
#                                   NP                                    |                |    |        |       |                      VP                     |
#           ________________________|_____                                |                |    |        |       |       _______________|_____                 |
#          |                             PRN                              VP               |    |        |       |      |        |            PP               |
#          |              ________________|_____________________      ____|_______         |    |        |       |      |        |       _____|______          |
#          NP            |                NP                    |    |           ADVP      |    |        NP     WHNP    |        NP     |            NP        |
#     _____|______       |     ___________|_____________        |    |            |        |    |        |       |      |        |      |      ______|____     |
#    JJ          NNS    VBP  NNS    ,     NN     ,     NNS     VBP  VBP           RB       CC   VB       NN      IN    VBZ      NNS     TO   VBG          NN   .
#    |            |      |    |     |     |      |      |       |    |            |        |    |        |       |      |        |      |     |           |    |
# Natural     disasters  –  storms  ,  flooding  ,  hurricanes  –  occur     infrequently but cause devastation that strains resources  to breaking     point  .
#
# AJ Graph Parser
# [S [NP [NP [JJ Natural] [NNS disasters]] [PRN [HYPN –] [NP [NNS storms] [, ,] [NN flooding] [, ,] [NNS hurricanes]] [HYPN –]]] [VP [VP [VBP occur] [ADVP [RB infrequently]]] [CC but] [VP [VB cause] [NP [NP [NN devastation]] [SBAR [WHNP [WDT that]] [S [VP [VBZ strains] [NP [NNS resources]] [PP [IN to] [NP [VBG breaking] [NN point]]]]]]]]] [. .]]
#
#                                                                                   S
#                                     ______________________________________________|____________________________________________________________________________
#                                    |                                                       VP                                                                  |
#                                    |                                       ________________|_____________                                                      |
#                                    |                                      |                |             VP                                                    |
#                                    |                                      |                |     ________|_______                                              |
#                                    |                                      |                |    |                NP                                            |
#                                    |                                      |                |    |         _______|_______________                              |
#                                    |                                      |                |    |        |                      SBAR                           |
#                                    |                                      |                |    |        |        _______________|______                       |
#                                    |                                      |                |    |        |       |                      S                      |
#                                    |                                      |                |    |        |       |                      |                      |
#                                    NP                                     |                |    |        |       |                      VP                     |
#           _________________________|_____                                 |                |    |        |       |       _______________|_____                 |
#          |                              PRN                               VP               |    |        |       |      |        |            PP               |
#          |              _________________|_____________________       ____|_______         |    |        |       |      |        |       _____|______          |
#          NP            |                 NP                    |     |           ADVP      |    |        NP     WHNP    |        NP     |            NP        |
#     _____|______       |      ___________|_____________        |     |            |        |    |        |       |      |        |      |      ______|____     |
#    JJ          NNS    HYPN  NNS    ,     NN     ,     NNS     HYPN  VBP           RB       CC   VB       NN     WDT    VBZ      NNS     IN   VBG          NN   .
#    |            |      |     |     |     |      |      |       |     |            |        |    |        |       |      |        |      |     |           |    |
# Natural     disasters  –   storms  ,  flooding  ,  hurricanes  –   occur     infrequently but cause devastation that strains resources  to breaking     point  .
#
# Gold vs LAL Parser
# Edit distance :21
# Recall =0.5384615384615384
# Precision =0.7777777777777778
# F1-Score =0.6363636363636364
# ID:  0 length: 21 state:  0 recall:53.85 prec:77.78 matched_brackets: 14 gold_brackets: 26 test_brackets: 18 cross_brackets:  0 words: 21 correct_tags: 15 tag_accracy:71.43
# Gold vs AJ Graph Parser
# Edit distance :19
# Recall =0.5384615384615384
# Precision =0.7777777777777778
# F1-Score =0.6363636363636364
# ID:  0 length: 21 state:  0 recall:53.85 prec:77.78 matched_brackets: 14 gold_brackets: 26 test_brackets: 18 cross_brackets:  0 words: 21 correct_tags: 17 tag_accracy:80.95
# LAL Parser vs AJ Graph Parser
# ID:  0 length: 21 state:  0 recall:100.00 prec:100.00 matched_brackets: 18 gold_brackets: 18 test_brackets: 18 cross_brackets:  0 words: 21 correct_tags: 17 tag_accracy:80.95
# -----------------
# GOLD
# [S [NP [NP [NNS Letters]]   [S [VP [VP [VBN delivered] [PP [IN on] [NP [NN time]]]]    [PP [IN by] [NP [ADJP [ADJP [ADJP [JJ old]]  [HYPH -]]  [JJ fashioned]] [NNS means]]]]]]    [VP [VBP are] [ADJP [ADVP [RB increasingly]] [JJ rare]]]   [S [ADVP [, ,] [RB so]]    [S [NP [PRP it]]     [VP [VP [VBZ is]      [ADVP [RB as]       [ADVP [RB well]]]]        [S [IN that]         [S [NP [DT that]]          [VP [VBZ is] [ADVP [RB not]           [NP [NP [DT the] [NP [ADJP [JJ only]] [NN option]]]            [ADJP [JJ available]]]]]]]]]]  [. .]]
#                                                                                                            S
#                     _______________________________________________________________________________________|_________________________________________________________________________
#                    |                                                           |                           S                                                                         |
#                    |                                                           |                       ____|_______                                                                  |
#                    |                                                           |                      |            S                                                                 |
#                    |                                                           |                      |         ___|____________                                                     |
#                    |                                                           |                      |        |                VP                                                   |
#                    |                                                           |                      |        |        ________|_________                                           |
#                    NP                                                          |                      |        |       |                  S                                          |
#     _______________|____________                                               |                      |        |       |              ____|____                                      |
#    |                            S                                              |                      |        |       |             |         S                                     |
#    |                            |                                              |                      |        |       |             |     ____|_______                              |
#    |                            VP                                             |                      |        |       |             |    |            VP                            |
#    |                ____________|_____________                                 |                      |        |       |             |    |     _______|___                          |
#    |               |                          PP                               |                      |        |       |             |    |    |          ADVP                       |
#    |               |             _____________|____                            |                      |        |       |             |    |    |    _______|____                     |
#    |               |            |                  NP                          |                      |        |       |             |    |    |   |            NP                   |
#    |               |            |              ____|______________             |                      |        |       |             |    |    |   |        ____|_____________       |
#    |               VP           |            ADJP                 |            VP                     |        |       VP            |    |    |   |       NP                 |      |
#    |         ______|___         |         ____|___________        |     _______|________              |        |    ___|___          |    |    |   |    ___|____              |      |
#    |        |          PP       |       ADJP              |       |    |               ADJP           |        |   |      ADVP       |    |    |   |   |        NP            |      |
#    |        |       ___|___     |    ____|____            |       |    |        ________|____         |        |   |    ___|____     |    |    |   |   |    ____|____         |      |
#    NP       |      |       NP   |  ADJP       |           |       |    |      ADVP           |       ADVP      NP  |   |       ADVP  |    NP   |   |   |  ADJP       |       ADJP    |
#    |        |      |       |    |   |         |           |       |    |       |             |     ___|____    |   |   |        |    |    |    |   |   |   |         |        |      |
#   NNS      VBN     IN      NN   IN  JJ       HYPH         JJ     NNS  VBP      RB            JJ   ,        RB PRP VBZ  RB       RB   IN   DT  VBZ  RB  DT  JJ        NN       JJ     .
#    |        |      |       |    |   |         |           |       |    |       |             |    |        |   |   |   |        |    |    |    |   |   |   |         |        |      |
# Letters delivered  on     time  by old        -       fashioned means are increasingly      rare  ,        so  it  is  as      well that that  is not the only     option available  .
#
# LAL Parser
# [S [S [NP [NP [NNS Letters]] [VP [VBN delivered] [PP [IN on] [NP [NN time]]] [PP [IN by] [NP [ADJP [JJ old] [: -] [VBN fashioned]] [NNS means]]]]] [VP [VBP are] [ADJP [RB increasingly] [JJ rare]]]] [, ,] [IN so] [S [NP [NP [PRP it]]] [VP [VBZ is] [ADJP [RB as] [RB well]] [SBAR [IN that] [S [NP [DT that]] [VP [VBZ is] [RB not] [NP [NP [DT the] [JJ only] [NN option]] [ADJP [JJ available]]]]]]]] [. .]]
#
#                                                                                                 S
#                                      ___________________________________________________________|_________________________________________________________________________
#                                     |                                                       |   |       S                                                                 |
#                                     |                                                       |   |    ___|___                                                              |
#                                     S                                                       |   |   |       VP                                                            |
#                     ________________|____________________________________                   |   |   |    ___|__________________                                           |
# ...
#  |         |     |     |       |    |     |          |       |     |     |      |     ___|___     |   |      |       |    |   |    |    |    |    |    |    ____|___     ___|___     |    ___|____      ___|____      |    |   |    ____|____     |
#  IN        NN    DT    JJ     NNP   CC   NNP        NNS     VBP    DT    JJ     NN   IN      DT   IN  DT     JJ     NNS   IN  DT  NNS   VB -LRB-  RB  NNP  NN       NN  IN     VBN   CC  NN       NN   IN      VBG  -RRB-  ,   VB  CC        VB   .
#  |         |     |     |       |    |     |          |       |     |     |      |    |       |    |   |      |       |    |   |    |    |    |    |    |   |        |   |       |    |   |        |    |        |     |    |   |   |         |    |
# For     example the original Brown and    C5      tagsets include  a  separate tag  for     each  of the different forms  of the verbs  do -LRB- e.g.  C5 tag      VDD for     did  and VDG      tag  for     doing -RRB-  ,   be and       have  .
#
# LAL Parser
# [S [PP [IN For] [NP [NN example]]] [NP [DT the] [JJ original] [NNP Brown] [CC and] [NNP C5] [NNS tagsets]] [VP [VBP include] [NP [NP [DT a] [JJ separate] [NN tag]] [PP [IN for] [NP [NP [DT each]] [PP [IN of] [NP [NP [DT the] [JJ different] [NNS forms]] [PP [IN of] [NP [DT the] [NNS verbs]]]]]]] [UCP [VBP do] [DT -LRB-] [NN e.g.] [NP [NP [NP [NP [NNP C5] [NN tag] [NNP VDD]] [PP [IN for] [ADJP [VBD did]]]] [CC and] [NP [NP [NNP VDG] [NN tag]] [PP [IN for] [S [VP [VBG doing]]]]]] [NN -RRB-]] [, ,] [VB be] [CC and] [VB have]]]] [. .]]
#
#                                                                                                                   S
#       ____________________________________________________________________________________________________________|______________________________________________________________________________________________________________
#      |                         |                                                          VP                                                                                                                                     |
#      |                         |                       ___________________________________|_______________________________________________                                                                                       |
#      |                         |                      |                                                                                   NP                                                                                     |
#      |                         |                      |            _______________________________________________________________________|_____________________________                                                         |
#      |                         |                      |           |              |                                                                                     UCP                                                       |
#      |                         |                      |           |              |                                               _______________________________________|___________________________________________________     |
#      |                         |                      |           |              PP                                             |    |    |                             NP                                      |   |   |   |    |
#      |                         |                      |           |           ___|____                                          |    |    |                         ____|__________________________________     |   |   |   |    |
#      |                         |                      |           |          |        NP                                        |    |    |                        NP                                      |    |   |   |   |    |
#      |                         |                      |           |          |    ____|___                                      |    |    |             ___________|____________________                   |    |   |   |   |    |
#      |                         |                      |           |          |   |        PP                                    |    |    |            |                |               NP                 |    |   |   |   |    |
#      |                         |                      |           |          |   |     ___|______________                       |    |    |            |                |        _______|_______           |    |   |   |   |    |
#      |                         |                      |           |          |   |    |                  NP                     |    |    |            NP               |       |               PP         |    |   |   |   |    |
#      |                         |                      |           |          |   |    |           _______|________              |    |    |         ___|_______         |       |            ___|____      |    |   |   |   |    |
#      PP                        |                      |           |          |   |    |          |                PP            |    |    |        |           PP       |       |           |        S     |    |   |   |   |    |
#   ___|_____                    |                      |           |          |   |    |          |             ___|___          |    |    |        |        ___|___     |       |           |        |     |    |   |   |   |    |
#  |         NP                  NP                     |           NP         |   NP   |          NP           |       NP        |    |    |        NP      |      ADJP  |       NP          |        VP    |    |   |   |   |    |
#  |         |      _____________|______________        |      _____|______    |   |    |    ______|_______     |    ___|____     |    |    |     ___|___    |       |    |    ___|___        |        |     |    |   |   |   |    |
#  IN        NN    DT    JJ     NNP   CC NNP   NNS     VBP    DT    JJ     NN  IN  DT   IN  DT     JJ     NNS   IN  DT      NNS  VBP   DT   NN  NNP  NN NNP  IN     VBD   CC NNP      NN      IN      VBG    NN   ,   VB  CC  VB   .
#  |         |     |     |       |    |   |     |       |     |     |      |   |   |    |   |      |       |    |   |        |    |    |    |    |   |   |   |       |    |   |       |       |        |     |    |   |   |   |    |
# For     example the original Brown and  C5 tagsets include  a  separate tag for each  of the different forms  of the     verbs  do -LRB- e.g.  C5 tag VDD for     did  and VDG     tag     for     doing -RRB-  ,   be and have  .
#
# AJ Graph Parser
# [S [PP [IN For] [NP [NN example]]] [NP [DT the] [JJ original] [NNP Brown] [CC and] [NNP C5] [NNS tagsets]] [VP [VBP include] [NP [NP [DT a] [JJ separate] [NN tag]] [PP [IN for] [NP [NP [DT each]] [PP [IN of] [NP [NP [DT the] [JJ different] [NNS forms]] [PP [IN of] [NP [DT the] [NNS verbs] [NP [VP [VBP do]] [PRN [-LRB- -LRB-] [RB e.g.] [NP [NP [NP [NNP C5] [NN tag] [NN VDD]] [PP [IN for] [S [VP [VBD did]]]]] [CC and] [NP [NP [NNP VDG] [NN tag]] [PP [IN for] [NP [VBG doing]]]]] [-RRB- -RRB-]]] [, ,] [VB be] [CC and] [VB have]]]]]]]]] [. .]]
#
#                                                                                                                   S
#       ____________________________________________________________________________________________________________|_________________________________________________________________________________________________________
#      |                         |                            VP                                                                                                                                                              |
#      |                         |                       _____|____________                                                                                                                                                   |
#      |                         |                      |                  NP                                                                                                                                                 |
#      |                         |                      |            ______|_______                                                                                                                                           |
#      |                         |                      |           |              PP                                                                                                                                         |
#      |                         |                      |           |           ___|____                                                                                                                                      |
#      |                         |                      |           |          |        NP                                                                                                                                    |
#      |                         |                      |           |          |    ____|__________                                                                                                                           |
#      |                         |                      |           |          |   |               PP                                                                                                                         |
#      |                         |                      |           |          |   |     __________|________________                                                                                                          |
#      |                         |                      |           |          |   |    |                           NP                                                                                                        |
#      |                         |                      |           |          |   |    |           ________________|___________________                                                                                      |
#      |                         |                      |           |          |   |    |          |                                    PP                                                                                    |
#      |                         |                      |           |          |   |    |          |             _______________________|________________________                                                             |
#      |                         |                      |           |          |   |    |          |            |                                                NP                                                           |
#      |                         |                      |           |          |   |    |          |            |    ____________________________________________|_______________________________________________________     |
#      |                         |                      |           |          |   |    |          |            |   |    |                               NP                                                  |   |   |   |    |
#      |                         |                      |           |          |   |    |          |            |   |    |     __________________________|_______                                            |   |   |   |    |
#      |                         |                      |           |          |   |    |          |            |   |    |    |                                 PRN                                          |   |   |   |    |
#      |                         |                      |           |          |   |    |          |            |   |    |    |     _____________________________|______________________________________     |   |   |   |    |
#      |                         |                      |           |          |   |    |          |            |   |    |    |    |    |                        NP                                     |    |   |   |   |    |
#      |                         |                      |           |          |   |    |          |            |   |    |    |    |    |             ___________|___________________                   |    |   |   |   |    |
#      |                         |                      |           |          |   |    |          |            |   |    |    |    |    |            NP              |               |                  |    |   |   |   |    |
#      |                         |                      |           |          |   |    |          |            |   |    |    |    |    |         ___|_______        |               |                  |    |   |   |   |    |
#      |                         |                      |           |          |   |    |          |            |   |    |    |    |    |        |           PP      |               NP                 |    |   |   |   |    |
#      |                         |                      |           |          |   |    |          |            |   |    |    |    |    |        |        ___|___    |        _______|_______           |    |   |   |   |    |
#      PP                        |                      |           |          |   |    |          |            |   |    |    |    |    |        |       |       S   |       |               PP         |    |   |   |   |    |
#   ___|_____                    |                      |           |          |   |    |          |            |   |    |    |    |    |        |       |       |   |       |            ___|____      |    |   |   |   |    |
#  |         NP                  NP                     |           NP         |   NP   |          NP           |   |    |    VP   |    |        NP      |       VP  |       NP          |        NP    |    |   |   |   |    |
#  |         |      _____________|______________        |      _____|______    |   |    |    ______|_______     |   |    |    |    |    |     ___|___    |       |   |    ___|___        |        |     |    |   |   |   |    |
#  IN        NN    DT    JJ     NNP   CC NNP   NNS     VBP    DT    JJ     NN  IN  DT   IN  DT     JJ     NNS   IN  DT  NNS  VBP -LRB-  RB  NNP  NN  NN  IN     VBD  CC NNP      NN      IN      VBG  -RRB-  ,   VB  CC  VB   .
#  |         |     |     |       |    |   |     |       |     |     |      |   |   |    |   |      |       |    |   |    |    |    |    |    |   |   |   |       |   |   |       |       |        |     |    |   |   |   |    |
# For     example the original Brown and  C5 tagsets include  a  separate tag for each  of the different forms  of the verbs  do -LRB- e.g.  C5 tag VDD for     did and VDG     tag     for     doing -RRB-  ,   be and have  .
#
# Gold vs LAL Parser
# Edit distance :49
# Recall =0.2777777777777778
# Precision =0.37037037037037035
# F1-Score =0.3174603174603175
# ID:  0 length: 40 state:  0 recall:27.78 prec:37.04 matched_brackets: 10 gold_brackets: 36 test_brackets: 27 cross_brackets: 10 words: 40 correct_tags: 33 tag_accracy:82.50
# Gold vs AJ Graph Parser
# Edit distance :34
# Recall =0.4444444444444444
# Precision =0.5714285714285714
# F1-Score =0.5
# ID:  0 length: 40 state:  0 recall:44.44 prec:57.14 matched_brackets: 16 gold_brackets: 36 test_brackets: 28 cross_brackets:  4 words: 40 correct_tags: 37 tag_accracy:92.50
# LAL Parser vs AJ Graph Parser
# ID:  0 length: 40 state:  0 recall:59.26 prec:57.14 matched_brackets: 16 gold_brackets: 27 test_brackets: 28 cross_brackets:  5 words: 40 correct_tags: 36 tag_accracy:90.00
# -----------------

# %%
# Overall metrics
print('LAL vs Gold')
print(f'Cross braketing: {np.mean(cb_1g)}')
print(f'Edit distance: {np.mean(ed_1g)}')
print('AJ vs Gold')
print(f'Cross braketing: {np.mean(cb_2g)}')
print(f'Edit distance: {np.mean(ed_2g)}')
# Out:
# LAL vs Gold
# Cross braketing: 1.6363636363636365
# Edit distance: 18.545454545454547
# AJ vs Gold
# Cross braketing: 1.1818181818181819
# Edit distance: 15.636363636363637

# %% [markdown]
# #### Print all prediction for Latex

# %%
# Print a block of text for Latex
# It contains a paragraph for the sentence 
# and a paragraph for each tree (gold, LAL, AJ)
def print_tree_latex(gold, parser1, parser2, counter):
  sentence = ('\\paragraph {Sentence ' + str(counter) + '} \\\\ \n' +
               '\\paragraph{GOLD} \n')
  sentence += str(gold).replace('$', '\$') + '\n'
  sentence += '\\paragraph{LAL} \n'
  sentence += str(parser1).replace('$', '\$') + '\n'
  sentence += '\\paragraph{AJ} \n'
  sentence += str(parser2).replace('$', '\$') + '\n'
  sentence += '\n'
  print(sentence)

# %%
counter = 0
for i, j, g in zip(cd_tree_p1, cd_tree_p2, cp_gold_final):
  counter += 1
  gold_tree = parser.create_from_bracket_string(g)
  test_tree_1 = parser.create_from_bracket_string(i)
  test_tree_2 = parser.create_from_bracket_string(j)
  print_tree_latex(gold_tree, test_tree_1, test_tree_2, counter)
  print()
# Out:
# \paragraph {Sentence 1} \\
# \paragraph{GOLD}
# (S (NP (PRP\$ My) (NP (NN aunt) (NP (POS 's) (NP (NN can) (NN opener))))) (VP (MD can) (VP (VB open) (NP (DT a) (NN drum)))) (. .))
# \paragraph{LAL}
# (S (NP (NP (PRP\$ My) (NN aunt) (POS 's)) (MD can) (VB opener)) (VP (MD can) (VP (VB open) (NP (DT a) (NN drum)))) (. .))
# \paragraph{AJ}
# (S (NP (NP (PRP\$ My) (NN aunt) (POS 's)) (MD can) (NN opener)) (VP (MD can) (VP (VB open) (NP (DT a) (NN drum)))) (. .))
#
#
#
# \paragraph {Sentence 2} \\
# \paragraph{GOLD}
# (S (NP (DT The) (NP (ADJP (JJ old)) (NN car))) (VP (V (VBD broke) (RP down)) (PP (IN in) (NP (DT the) (NP (NN car) (NN park))))) (. .))
# \paragraph{LAL}
# (S (NP (DT The) (JJ old) (NN car)) (VP (VBD broke) (PRT (RB down)) (PP (IN in) (NP (DT the) (NN car) (NN park)))) (. .))
# \paragraph{AJ}
# (S (NP (DT The) (JJ old) (NN car)) (VP (VBD broke) (PRT (RP down)) (PP (IN in) (NP (DT the) (NN car) (NN park)))) (. .))
#
#
#
# \paragraph {Sentence 3} \\
# \paragraph{GOLD}
# (S (NP (ADVP (RB At) (ADVP (RBS least) (CD two))) (NNS men)) (VP (VP (V (VBD broke) (RP in))) (CONJP (CC and) (VP (VBD stole) (NP (PRP\$ my) (NN TV))))) (. .))
# \paragraph{LAL}
# (S (NP (QP (IN At) (JJS least) (CD two)) (NNS men)) (VP (VP (VBD broke) (PRT (IN in))) (CC and) (VP (VB stole) (NP (PRP\$ my) (NN TV)))) (. .))
# \paragraph{AJ}
# (S (NP (QP (RB At) (JJS least) (CD two)) (NNS men)) (VP (VP (VBD broke) (PRT (RP in))) (CC and) (VP (VBD stole) (NP (PRP\$ my) (NN TV)))) (. .))
#
#
#
# \paragraph {Sentence 4} \\
# \paragraph{GOLD}
# (S (NP (NP (NNP Kim)) (CONJP (CC and) (NP (NNP Sandy)))) (VP (ADVP (RB both)) (VP (V (VBD broke) (RP up)) (PP (IN with) (NP (PRP\$ their) (NNS partners))))) (. .))
# \paragraph{LAL}
# (S (NP (NNP Kim) (CC and) (NNP Sandy)) (DT both) (VP (VBD broke) (PRT (RP up)) (PP (IN with) (NP (PRP\$ their) (NNS partners)))) (. .))
# \paragraph{AJ}
# (S (NP (NNP Kim) (CC and) (NNP Sandy)) (DT both) (VP (VBD broke) (PRT (RP up)) (PP (IN with) (NP (PRP\$ their) (NNS partners)))) (. .))
#
#
#
# \paragraph {Sentence 5} \\
# \paragraph{GOLD}
# (S (NP (NP (DT The) (NN horse)) (CONJP (ADVP (RB as) (ADVP (RB well)) (ADVP (RB as))) (NP (NP (DT the) (NNS rabbits)) (S (WDT which) (S (PRP we) (VP (VBD wanted) (VP (TO to) (VB eat)))))))) (VP (VBZ has) (VP (VBN escaped))) (. .))
# \paragraph{LAL}
# (S (NP (NP (DT The) (NN horse)) (CONJP (RB as) (RB well) (IN as)) (NP (NP (DT the) (NNS rabbits)) (SBAR (WHNP (WDT which)) (S (NP (PRP we)) (VP (VBD wanted) (S (VP (TO to) (VP (VB eat))))))))) (VP (VBZ has) (VP (VBN escaped))) (. .))
# \paragraph{AJ}
# (S (NP (NP (DT The) (NN horse)) (CONJP (RB as) (RB well) (IN as)) (NP (NP (DT the) (NNS rabbits)) (SBAR (WHNP (WDT which)) (S (NP (PRP we)) (VP (VBD wanted) (S (VP (TO to) (VP (VB eat))))))))) (VP (VBZ has) (VP (VBN escaped))) (. .))
#
#
#
# \paragraph {Sentence 6} \\
# \paragraph{GOLD}
# (S (NP (PRP It)) (VP (VBD was) (NP (NP (PRP\$ my) (NP (NN aunt) (NP (POS 's) (NN car)))) (S (WDT which) (S (NP (PRP we)) (VP (VP (VP (VBD sold) (PP (IN at) (NP (NN auction)))) (ADVP (RB last) (NP (NN year)))) (PP (IN in) (NP (NNP February)))))))) (. .))
# \paragraph{LAL}
# (S (NP (PRP It)) (VP (VBD was) (NP (NP (NP (PRP\$ my) (NN aunt) (POS 's)) (NN car)) (SBAR (WHNP (WDT which)) (S (NP (PRP we)) (VP (VBD sold) (PP (IN at) (NP (NN auction))) (NP (JJ last) (NN year)) (PP (IN in) (NP (NNP February)))))))) (. .))
# \paragraph{AJ}
# (S (NP (PRP It)) (VP (VBD was) (NP (NP (NP (PRP\$ my) (NN aunt) (POS 's)) (NN car)) (SBAR (WHNP (WDT which)) (S (NP (PRP we)) (VP (VBD sold) (PP (IN at) (NP (NN auction))) (NP (JJ last) (NN year)) (PP (IN in) (NP (NNP February)))))))) (. .))
#
#
#
# \paragraph {Sentence 7} \\
# \paragraph{GOLD}
# (S (NP (NP (ADJP (JJ Natural)) (NNS disasters)) (PRN (PRN (: –) (NP (NP (NP (NNS storms)) (LST (, ,) (NP (NN flooding)))) (LST (, ,) (NP (NNS hurricanes))))) (: –))) (VP (VP (VP (VBP occur)) (ADVP (RB infrequently))) (CONJP (CC but) (VP (VBP cause) (NP (NN devastation) (S (WDT that) (VP (VP (VBZ strains) (NP (NNS resources))) (PP (IN to) (NP (NN breaking) (NN point))))))))) (. .))
# \paragraph{LAL}
# (S (NP (NP (JJ Natural) (NNS disasters)) (PRN (VBP –) (NP (NNS storms) (, ,) (NN flooding) (, ,) (NNS hurricanes)) (VBP –))) (VP (VP (VBP occur) (ADVP (RB infrequently))) (CC but) (VP (VB cause) (NP (NP (NN devastation)) (SBAR (WHNP (IN that)) (S (VP (VBZ strains) (NP (NNS resources)) (PP (TO to) (NP (VBG breaking) (NN point))))))))) (. .))
# \paragraph{AJ}
# (S (NP (NP (JJ Natural) (NNS disasters)) (PRN (HYPN –) (NP (NNS storms) (, ,) (NN flooding) (, ,) (NNS hurricanes)) (HYPN –))) (VP (VP (VBP occur) (ADVP (RB infrequently))) (CC but) (VP (VB cause) (NP (NP (NN devastation)) (SBAR (WHNP (WDT that)) (S (VP (VBZ strains) (NP (NNS resources)) (PP (IN to) (NP (VBG breaking) (NN point))))))))) (. .))
#
#
#
# \paragraph {Sentence 8} \\
# \paragraph{GOLD}
# (S (NP (NP (NNS Letters)) (S (VP (VP (VBN delivered) (PP (IN on) (NP (NN time)))) (PP (IN by) (NP (ADJP (ADJP (ADJP (JJ old)) (HYPH -)) (JJ fashioned)) (NNS means)))))) (VP (VBP are) (ADJP (ADVP (RB increasingly)) (JJ rare))) (S (ADVP (, ,) (RB so)) (S (NP (PRP it)) (VP (VP (VBZ is) (ADVP (RB as) (ADVP (RB well)))) (S (IN that) (S (NP (DT that)) (VP (VBZ is) (ADVP (RB not) (NP (NP (DT the) (NP (ADJP (JJ only)) (NN option))) (ADJP (JJ available)))))))))) (. .))
# \paragraph{LAL}
# (S (S (NP (NP (NNS Letters)) (VP (VBN delivered) (PP (IN on) (NP (NN time))) (PP (IN by) (NP (ADJP (JJ old) (: -) (VBN fashioned)) (NNS means))))) (VP (VBP are) (ADJP (RB increasingly) (JJ rare)))) (, ,) (IN so) (S (NP (NP (PRP it))) (VP (VBZ is) (ADJP (RB as) (RB well)) (SBAR (IN that) (S (NP (DT that)) (VP (VBZ is) (RB not) (NP (NP (DT the) (JJ only) (NN option)) (ADJP (JJ available)))))))) (. .))
# \paragraph{AJ}
# (S (S (NP (NP (NNS Letters)) (VP (VBD delivered) (PP (IN on) (NP (NN time))) (PP (IN by) (NP (JJ old) (HYPN -) (JJ fashioned) (NNS means))))) (VP (VBP are) (ADJP (RB increasingly) (JJ rare)))) (, ,) (IN so) (S (NP (NP (PRP it))) (VP (VBZ is) (ADVP (RB as) (RB well)) (SBAR (IN that) (S (NP (DT that)) (VP (VBZ is) (RB not) (NP (NP (DT the) (JJ only) (NN option)) (ADJP (JJ available)))))))) (. .))
#
#
#
# \paragraph {Sentence 9} \\
# \paragraph{GOLD}
# (S (NP (NNP English)) (VP (ADVP (RB also)) (VP (VBZ has) (NP (NP (ADJP (JJ many)) (NP (NNS words) (PP (IN of) (NP (NP (ADJP (ADJP (JJR more)) (CONJP (CC or) (ADJP (JJR less)))) (NP (ADJP (JJ unique)) (NN function))) (, ,) (VP (VP (VBG including) (NP (NP (NNS interjections)) (PRN (-LRB- -LRB-) (LST (LST (UH oh) (, ,)) (UH ah)) (-RRB- -RRB-))) (, ,) (NP (NP (NNS negatives)) (PRN (-LRB- -LRB-) (LST (LST (RB no) (, ,)) (RB not)) (-RRB- -RRB-))) (, ,) (NP (NP (NN politeness) (NNS markers)) (PRN (-LRB- -LRB-) (LST (LST (UH please) (, ,)) (VP (VB thank) (NP (PRP you)))) (-RRB- -RRB-))) (, ,) (CONJP (CC and) (ADVP (ADVP (DT the) (ADVP (ADJP (JJ existential)) (`` ') (ADVP (RB there)) ('' '))) (PRN (-LRB- -LRB-) (S (EX there) (VP (VBP are) (NP (NNS horses) (CONJP (CC but) (ADVP (RB not) (NP (NNS unicorns))))))) (-RRB- -RRB-))))) (PP (IN among) (NP (NNS others))))))))))) (. .))
# \paragraph{LAL}
# (S (NP (NNP English)) (ADVP (RB also)) (VP (VBZ has) (NP (NP (JJ many) (NNS words)) (PP (IN of) (NP (ADJP (JJR more) (CC or) (JJR less)) (JJ unique) (NN function))) (, ,) (PP (VBG including) (NP (NP (NP (NNS interjections)) (PRN (NNP -LRB-) (INTJ (INTJ (UH oh)) (, ,) (JJ ah)) (NN -RRB-))) (, ,) (NP (NP (NNS negatives)) (PRN (VBP -LRB-) (INTJ (DT no) (, ,) (RB not)) (NNP -RRB-))) (, ,) (NP (NP (NN politeness) (NNS markers)) (PRN (VBP -LRB-) (INTJ (INTJ (NN please)) (, ,) (NN thank) (PRP you)) (VBP -RRB-))) (, ,) (CC and) (NP (NP (NP (DT the) (JJ existential) (POS ') (EX there) ('' ')) (PRN (NN -LRB-) (S (NP (EX there)) (VP (VBP are) (NP (NP (NNS horses)) (CC but) (RB not) (NP (JJ unicorns))))) (NNP -RRB-))) (PP (IN among) (NP (NNS others)))))))) (. .))
# \paragraph{AJ}
# (S (NP (NNP English)) (ADVP (RB also)) (VP (VBZ has) (NP (NP (JJ many) (NNS words)) (PP (IN of) (NP (ADJP (ADVP (JJR more) (CC or) (RBR less)) (JJ unique)) (NN function))) (, ,) (PP (VBG including) (NP (NP (NP (NNS interjections)) (PRN (-LRB- -LRB-) (INTJ (UH oh) (, ,) (UH ah)) (-RRB- -RRB-))) (, ,) (NP (NP (NNS negatives)) (PRN (-LRB- -LRB-) (INTJ (UH no) (, ,) (RB not)) (-RRB- -RRB-))) (, ,) (NP (NP (NN politeness) (NNS markers)) (PRN (-LRB- -LRB-) (NP (INTJ (UH please)) (, ,) (VBP thank) (PRP you)) (-RRB- -RRB-))) (, ,) (CC and) (NP (NP (NP (DT the) (JJ existential) (`` ') (EX there) ('' ')) (PRN (-LRB- -LRB-) (S (NP (EX there)) (VP (VBP are) (NP (NP (NNS horses)) (CC but) (RB not) (NP (NNS unicorns))))) (-RRB- -RRB-))) (PP (IN among) (NP (NNS others)))))))) (. .))
#
#
#
# \paragraph {Sentence 10} \\
# \paragraph{GOLD}
# (S (NP (DT The) (NP (NNP Penn) (NP (NNP Treebank) (NP (NN tagset))))) (VP (VP (VBD was) (VBN culled)) (PP (IN from) (NP (DT the) (ADJP (JJ original) (NP (NP (CD 87) (HYPH -)) (NP (NN tag)))) (NP (NN tagset) (PP (IN for) (NP (DT the) (NP (NNP Brown) (NP (NNP Corpus))))))))) (. .))
# \paragraph{LAL}
# (S (NP (DT The) (NNP Penn) (NNP Treebank) (NN tagset)) (VP (VBD was) (VP (VBN culled) (PP (IN from) (NP (NP (DT the) (JJ original) (ADJP (CD 87) (: -) (NN tag)) (NN tagset)) (PP (IN for) (NP (DT the) (NNP Brown) (NNP Corpus))))))) (. .))
# \paragraph{AJ}
# (S (NP (DT The) (NNP Penn) (NNP Treebank) (NN tagset)) (VP (VBD was) (VP (VBN culled) (PP (IN from) (NP (NP (DT the) (JJ original) (CD 87) (HYPN -) (NN tag) (NN tagset)) (PP (IN for) (NP (DT the) (NNP Brown) (NNP Corpus))))))) (. .))
#
#
#
# \paragraph {Sentence 11} \\
# \paragraph{GOLD}
# (S (PP (IN For) (NP (NN example))) (S (NP (DT the) (ADJP (JJ original) (NP (NNP Brown)) (CONJP (CC and) (NP (NP (NNP C5)) (NNS tagsets))))) (VP (VBP include) (NP (DT a) (ADJP (JJ separate) (NP (NN tag) (PP (PP (IN for) (DT each)) (PP (IN of) (NP (DT the) (ADJP (JJ different) (NP (NNS forms) (PP (IN of) (NP (DT the) (NP (NNS verbs) (LST (LST (LST (VB do) (PRN (-LRB- -LRB-) (ADVP (ADVP (RB e.g.) (NP (NNP C5) (NP (NN tag) (NN VDD))) (PP (IN for) (VBN did))) (CONJP (CC and) (NP (NN VDG) (NN tag)) (PP (IN for) (VBG doing)))) (-RRB- -RRB-))) (, ,) (VB be)) (CONJP (CC and) (VB have)))))))))))))))) (. .))
# \paragraph{LAL}
# (S (PP (IN For) (NP (NN example))) (NP (DT the) (JJ original) (NNP Brown) (CC and) (NNP C5) (NNS tagsets)) (VP (VBP include) (NP (NP (DT a) (JJ separate) (NN tag)) (PP (IN for) (NP (NP (DT each)) (PP (IN of) (NP (NP (DT the) (JJ different) (NNS forms)) (PP (IN of) (NP (DT the) (NNS verbs))))))) (UCP (VBP do) (DT -LRB-) (NN e.g.) (NP (NP (NP (NP (NNP C5) (NN tag) (NNP VDD)) (PP (IN for) (ADJP (VBD did)))) (CC and) (NP (NP (NNP VDG) (NN tag)) (PP (IN for) (S (VP (VBG doing)))))) (NN -RRB-)) (, ,) (VB be) (CC and) (VB have)))) (. .))
# \paragraph{AJ}
# (S (PP (IN For) (NP (NN example))) (NP (DT the) (JJ original) (NNP Brown) (CC and) (NNP C5) (NNS tagsets)) (VP (VBP include) (NP (NP (DT a) (JJ separate) (NN tag)) (PP (IN for) (NP (NP (DT each)) (PP (IN of) (NP (NP (DT the) (JJ different) (NNS forms)) (PP (IN of) (NP (DT the) (NNS verbs) (NP (VP (VBP do)) (PRN (-LRB- -LRB-) (RB e.g.) (NP (NP (NP (NNP C5) (NN tag) (NN VDD)) (PP (IN for) (S (VP (VBD did))))) (CC and) (NP (NP (NNP VDG) (NN tag)) (PP (IN for) (NP (VBG doing))))) (-RRB- -RRB-))) (, ,) (VB be) (CC and) (VB have))))))))) (. .))

# %% [markdown]
# #### Overall scores

# %%
# Writing prediction in right format
with open('cp_lal.txt', 'w', encoding='utf-8') as f:
   f.write(''.join(cd_tree_p1))
with open('cp_aj.txt', 'w', encoding='utf-8') as f:
   f.write(''.join(cd_tree_p2)) 
with open('cp_gold.txt', 'w', encoding='utf-8') as f:
   f.write('\n'.join(cp_gold_final))

# %%
# PARSEVAL for all sentences GOLD vs LAL
s = Scorer()
gold_path = 'cp_gold.txt'
test_path = 'cp_lal.txt'
result_path = 'result1g.txt'

s.evalb(gold_path, test_path, result_path)

# %%
# PARSEVAL for all sentences GOLD vs LAL
s = Scorer()
gold_path = 'cp_gold.txt'
test_path = 'cp_aj.txt'
result_path = 'result2g.txt'

s.evalb(gold_path, test_path, result_path)

# %% [markdown]
# ### Comparing Dependency prediction

# %%
all_uas1 = []
all_uas2 = []
all_las1 = []
all_las2 = []
counter = 0

# Create a dir to store svgs
if (not os.path.exists("images")):
    os.mkdir("images")

for word, deps_t, heads_t, sent, gold, gold_words in zip(words_to_use, new_dep_labels,
                                   new_dep_heads, dp_tree_p2, dp_gold_to_use, final_words_w_index):
  counter += 1
  # Visualising GOLD tree and save it as SVG
  try:
    doc = Doc(nlp.vocab, words=gold_words, deps=gold[0], heads=gold[1])
    displacy.render(doc,jupyter=True)
    svg = displacy.render(doc, style="dep", jupyter=False)
    file_name = f'{counter}_gold'
    output_path = Path("./images/" + file_name)
    output_path.open("w", encoding="utf-8").write(svg)
  except Exception as e:
    print(e)
  
  # Visualising LAL tree and save it as SVG
  doc = Doc(nlp.vocab, words=word, deps=deps_t, heads=heads_t)
  displacy.render(doc,jupyter=True)
  svg = displacy.render(doc, style="dep", jupyter=False)
  file_name = f'{counter}_lal'
  output_path = Path("./images/" + file_name)
  output_path.open("w", encoding="utf-8").write(svg)

  #Preprocess AJ prediction
  words = []
  deps2 = []
  heads2 = []
  for i in sent:
    words += [i.form]
    if i.deprel == 'root':
      deps2 += ['ROOT']
      heads2 += [None]
    else:
      deps2 += [i.deprel]
      heads2 += [i.head-1]

  # Visualising AJ tree and save it as SVG
  doc = Doc(nlp.vocab, words=words, deps=deps2, heads=heads2)
  displacy.render(doc,jupyter=True) 
  svg = displacy.render(doc, style="dep", jupyter=False)
  file_name = f'{counter}_aj'
  output_path = Path("./images/" + file_name)
  output_path.open("w", encoding="utf-8").write(svg)

  #Comparison
  # GOLD vs LAL
  print('LAL vs Gold')
  uas1 = []
  las1 = []
  for i,j, hi, hj in zip(deps_t, gold[0], heads_t, gold[1]):
    # Ignore punct relations
    if i != 'punct':
      uas1 += [hi==hj]
  # UAS score
  print(f'UAS: {statistics.mean(uas1)}')
  for i,j, hi, hj in zip(deps_t, gold[0], heads_t, gold[1]):
    if i != 'punct':
      las1 += [i==j and hi==hj]
  #LAS score
  print(f'LAS: {statistics.mean(las1)}')

  # GOLD vs AJ
  print('AJ vs Gold')
  uas2 = []
  las2 = []
  for i,j, hi, hj in zip(deps2, gold[0], heads2, gold[1]):
    if j != 'punct':
      uas2 += [hi==hj]
    if (i == 'punct' or j == 'punct') and i!=j:
      print(i,j)
      print('-------------------------------------')
  print(f'UAS: {statistics.mean(uas2)}')
  for i,j, hi, hj in zip(deps2, gold[0], heads2, gold[1]):
    if j != 'punct':
      las2 += [i==j and hi==hj]
  print(f'LAS: {statistics.mean(las2)}')

  #Store metrics
  all_uas1 += [(statistics.mean(uas1), len(uas1))]
  all_uas2 += [(statistics.mean(uas2), len(uas2))]
  all_las1 += [(statistics.mean(las1), len(las1))]
  all_las2 += [(statistics.mean(las2), len(las2))]
  print('----------------')  

tot = 0
for i in range(len(all_uas1)):
  tot += all_uas1[i][1]
  all_uas1[i] = all_uas1[i][0]*all_uas1[i][1]
  all_uas2[i] = all_uas2[i][0]*all_uas2[i][1]
  all_las1[i] = all_las1[i][0]*all_las1[i][1]
  all_las2[i] = all_las2[i][0]*all_las2[i][1]

# Overall results
print(f'MEAN UAS LAL: {sum(all_uas1)/tot}')
print(f'MEAN LAS LAL: {sum(all_las1)/tot}')
print(f'MEAN UAS AJ: {sum(all_uas2)/tot}')
print(f'MEAN LAS AJ: {sum(all_las2)/tot}')
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="1dc3547d47644bd3acca7e35b8161aeb-0" class="displacy" width="1625" height="312.0" direction="ltr" style="max-width: none; height: 312.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">My</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="225">aunt</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="400">'s+</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="575">can</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="750">opener</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="925">can</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="925"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="1100">open</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="1275">a</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1275"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="1450">drum .</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1450"></tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-1dc3547d47644bd3acca7e35b8161aeb-0-0" stroke-width="2px" d="M70,177.0 C70,89.5 220.0,89.5 220.0,177.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-1dc3547d47644bd3acca7e35b8161aeb-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">poss</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,179.0 L62,167.0 78,167.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-1dc3547d47644bd3acca7e35b8161aeb-0-1" stroke-width="2px" d="M245,177.0 C245,2.0 750.0,2.0 750.0,177.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-1dc3547d47644bd3acca7e35b8161aeb-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">poss</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M245,179.0 L237,167.0 253,167.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-1dc3547d47644bd3acca7e35b8161aeb-0-2" stroke-width="2px" d="M245,177.0 C245,89.5 395.0,89.5 395.0,177.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-1dc3547d47644bd3acca7e35b8161aeb-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">possessive</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M395.0,179.0 L403.0,167.0 387.0,167.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-1dc3547d47644bd3acca7e35b8161aeb-0-3" stroke-width="2px" d="M595,177.0 C595,89.5 745.0,89.5 745.0,177.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-1dc3547d47644bd3acca7e35b8161aeb-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nn</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M595,179.0 L587,167.0 603,167.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-1dc3547d47644bd3acca7e35b8161aeb-0-4" stroke-width="2px" d="M770,177.0 C770,2.0 1100.0,2.0 1100.0,177.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-1dc3547d47644bd3acca7e35b8161aeb-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M770,179.0 L762,167.0 778,167.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-1dc3547d47644bd3acca7e35b8161aeb-0-5" stroke-width="2px" d="M945,177.0 C945,89.5 1095.0,89.5 1095.0,177.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-1dc3547d47644bd3acca7e35b8161aeb-0-5" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">aux</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M945,179.0 L937,167.0 953,167.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-1dc3547d47644bd3acca7e35b8161aeb-0-6" stroke-width="2px" d="M1295,177.0 C1295,89.5 1445.0,89.5 1445.0,177.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-1dc3547d47644bd3acca7e35b8161aeb-0-6" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M1295,179.0 L1287,167.0 1303,167.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-1dc3547d47644bd3acca7e35b8161aeb-0-7" stroke-width="2px" d="M1120,177.0 C1120,2.0 1450.0,2.0 1450.0,177.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-1dc3547d47644bd3acca7e35b8161aeb-0-7" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">dobj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M1450.0,179.0 L1458.0,167.0 1442.0,167.0" fill="currentColor"/>
# </g>
# </svg></span>
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="db34420223964a15b2c9ef195a6cf2e2-0" class="displacy" width="1625" height="312.0" direction="ltr" style="max-width: none; height: 312.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">My</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="225">aunt</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="400">'s</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="575">can</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="750">opener</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="925">can</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="925"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="1100">open</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="1275">a</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1275"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="1450">drum .</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1450"></tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-db34420223964a15b2c9ef195a6cf2e2-0-0" stroke-width="2px" d="M70,177.0 C70,89.5 220.0,89.5 220.0,177.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-db34420223964a15b2c9ef195a6cf2e2-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">poss</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,179.0 L62,167.0 78,167.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-db34420223964a15b2c9ef195a6cf2e2-0-1" stroke-width="2px" d="M245,177.0 C245,2.0 575.0,2.0 575.0,177.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-db34420223964a15b2c9ef195a6cf2e2-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">poss</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M245,179.0 L237,167.0 253,167.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-db34420223964a15b2c9ef195a6cf2e2-0-2" stroke-width="2px" d="M245,177.0 C245,89.5 395.0,89.5 395.0,177.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-db34420223964a15b2c9ef195a6cf2e2-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">possessive</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M395.0,179.0 L403.0,167.0 387.0,167.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-db34420223964a15b2c9ef195a6cf2e2-0-3" stroke-width="2px" d="M595,177.0 C595,2.0 1100.0,2.0 1100.0,177.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-db34420223964a15b2c9ef195a6cf2e2-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">aux</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M595,179.0 L587,167.0 603,167.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-db34420223964a15b2c9ef195a6cf2e2-0-4" stroke-width="2px" d="M595,177.0 C595,89.5 745.0,89.5 745.0,177.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-db34420223964a15b2c9ef195a6cf2e2-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">dep</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M745.0,179.0 L753.0,167.0 737.0,167.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-db34420223964a15b2c9ef195a6cf2e2-0-5" stroke-width="2px" d="M945,177.0 C945,89.5 1095.0,89.5 1095.0,177.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-db34420223964a15b2c9ef195a6cf2e2-0-5" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">aux</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M945,179.0 L937,167.0 953,167.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-db34420223964a15b2c9ef195a6cf2e2-0-6" stroke-width="2px" d="M1295,177.0 C1295,89.5 1445.0,89.5 1445.0,177.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-db34420223964a15b2c9ef195a6cf2e2-0-6" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M1295,179.0 L1287,167.0 1303,167.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-db34420223964a15b2c9ef195a6cf2e2-0-7" stroke-width="2px" d="M1120,177.0 C1120,2.0 1450.0,2.0 1450.0,177.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-db34420223964a15b2c9ef195a6cf2e2-0-7" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">dobj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M1450.0,179.0 L1458.0,167.0 1442.0,167.0" fill="currentColor"/>
# </g>
# </svg></span>
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="228fca1b20164666a5c8c59f985103cb-0" class="displacy" width="1625" height="312.0" direction="ltr" style="max-width: none; height: 312.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">My</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="225">aunt</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="400">'s</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="575">can</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="750">opener</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="925">can</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="925"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="1100">open</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="1275">a</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1275"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="1450">drum .</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1450"></tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-228fca1b20164666a5c8c59f985103cb-0-0" stroke-width="2px" d="M70,177.0 C70,89.5 220.0,89.5 220.0,177.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-228fca1b20164666a5c8c59f985103cb-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">poss</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,179.0 L62,167.0 78,167.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-228fca1b20164666a5c8c59f985103cb-0-1" stroke-width="2px" d="M245,177.0 C245,2.0 750.0,2.0 750.0,177.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-228fca1b20164666a5c8c59f985103cb-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">poss</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M245,179.0 L237,167.0 253,167.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-228fca1b20164666a5c8c59f985103cb-0-2" stroke-width="2px" d="M245,177.0 C245,89.5 395.0,89.5 395.0,177.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-228fca1b20164666a5c8c59f985103cb-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">possessive</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M395.0,179.0 L403.0,167.0 387.0,167.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-228fca1b20164666a5c8c59f985103cb-0-3" stroke-width="2px" d="M595,177.0 C595,89.5 745.0,89.5 745.0,177.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-228fca1b20164666a5c8c59f985103cb-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">dep</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M595,179.0 L587,167.0 603,167.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-228fca1b20164666a5c8c59f985103cb-0-4" stroke-width="2px" d="M770,177.0 C770,2.0 1100.0,2.0 1100.0,177.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-228fca1b20164666a5c8c59f985103cb-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M770,179.0 L762,167.0 778,167.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-228fca1b20164666a5c8c59f985103cb-0-5" stroke-width="2px" d="M945,177.0 C945,89.5 1095.0,89.5 1095.0,177.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-228fca1b20164666a5c8c59f985103cb-0-5" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">aux</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M945,179.0 L937,167.0 953,167.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-228fca1b20164666a5c8c59f985103cb-0-6" stroke-width="2px" d="M1295,177.0 C1295,89.5 1445.0,89.5 1445.0,177.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-228fca1b20164666a5c8c59f985103cb-0-6" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M1295,179.0 L1287,167.0 1303,167.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-228fca1b20164666a5c8c59f985103cb-0-7" stroke-width="2px" d="M1120,177.0 C1120,2.0 1450.0,2.0 1450.0,177.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-228fca1b20164666a5c8c59f985103cb-0-7" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">dobj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M1450.0,179.0 L1458.0,167.0 1442.0,167.0" fill="currentColor"/>
# </g>
# </svg></span>
# LAL vs Gold
# UAS: 0.6666666666666666
# LAS: 0.6666666666666666
# AJ vs Gold
# UAS: 1
# LAS: 0.8888888888888888
# ----------------
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="2b33b2aa30a446e5b9756447417d4a37-0" class="displacy" width="1625" height="399.5" direction="ltr" style="max-width: none; height: 399.5px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="50">The</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="225">old</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="400">car</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="575">broke</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="750">down</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="925">in</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="925"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="1100">The</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="1275">car</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1275"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="1450">park .</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1450"></tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-2b33b2aa30a446e5b9756447417d4a37-0-0" stroke-width="2px" d="M70,264.5 C70,89.5 395.0,89.5 395.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-2b33b2aa30a446e5b9756447417d4a37-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,266.5 L62,254.5 78,254.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-2b33b2aa30a446e5b9756447417d4a37-0-1" stroke-width="2px" d="M245,264.5 C245,177.0 390.0,177.0 390.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-2b33b2aa30a446e5b9756447417d4a37-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">amod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M245,266.5 L237,254.5 253,254.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-2b33b2aa30a446e5b9756447417d4a37-0-2" stroke-width="2px" d="M420,264.5 C420,177.0 565.0,177.0 565.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-2b33b2aa30a446e5b9756447417d4a37-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M420,266.5 L412,254.5 428,254.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-2b33b2aa30a446e5b9756447417d4a37-0-3" stroke-width="2px" d="M595,264.5 C595,177.0 740.0,177.0 740.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-2b33b2aa30a446e5b9756447417d4a37-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">prt</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M740.0,266.5 L748.0,254.5 732.0,254.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-2b33b2aa30a446e5b9756447417d4a37-0-4" stroke-width="2px" d="M595,264.5 C595,89.5 920.0,89.5 920.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-2b33b2aa30a446e5b9756447417d4a37-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">prep</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M920.0,266.5 L928.0,254.5 912.0,254.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-2b33b2aa30a446e5b9756447417d4a37-0-5" stroke-width="2px" d="M1120,264.5 C1120,89.5 1445.0,89.5 1445.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-2b33b2aa30a446e5b9756447417d4a37-0-5" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M1120,266.5 L1112,254.5 1128,254.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-2b33b2aa30a446e5b9756447417d4a37-0-6" stroke-width="2px" d="M1295,264.5 C1295,177.0 1440.0,177.0 1440.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-2b33b2aa30a446e5b9756447417d4a37-0-6" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nn</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M1295,266.5 L1287,254.5 1303,254.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-2b33b2aa30a446e5b9756447417d4a37-0-7" stroke-width="2px" d="M945,264.5 C945,2.0 1450.0,2.0 1450.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-2b33b2aa30a446e5b9756447417d4a37-0-7" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">pobj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M1450.0,266.5 L1458.0,254.5 1442.0,254.5" fill="currentColor"/>
# </g>
# </svg></span>
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="9b11a3ff28404f4085a9e8785b7c0c56-0" class="displacy" width="1625" height="399.5" direction="ltr" style="max-width: none; height: 399.5px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="50">The</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="225">old</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="400">car</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="575">broke</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="750">down</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="925">in</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="925"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="1100">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="1275">car</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1275"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="1450">park .</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1450"></tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-9b11a3ff28404f4085a9e8785b7c0c56-0-0" stroke-width="2px" d="M70,264.5 C70,89.5 395.0,89.5 395.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-9b11a3ff28404f4085a9e8785b7c0c56-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,266.5 L62,254.5 78,254.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-9b11a3ff28404f4085a9e8785b7c0c56-0-1" stroke-width="2px" d="M245,264.5 C245,177.0 390.0,177.0 390.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-9b11a3ff28404f4085a9e8785b7c0c56-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">amod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M245,266.5 L237,254.5 253,254.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-9b11a3ff28404f4085a9e8785b7c0c56-0-2" stroke-width="2px" d="M420,264.5 C420,177.0 565.0,177.0 565.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-9b11a3ff28404f4085a9e8785b7c0c56-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M420,266.5 L412,254.5 428,254.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-9b11a3ff28404f4085a9e8785b7c0c56-0-3" stroke-width="2px" d="M595,264.5 C595,177.0 740.0,177.0 740.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-9b11a3ff28404f4085a9e8785b7c0c56-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">prt</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M740.0,266.5 L748.0,254.5 732.0,254.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-9b11a3ff28404f4085a9e8785b7c0c56-0-4" stroke-width="2px" d="M595,264.5 C595,89.5 920.0,89.5 920.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-9b11a3ff28404f4085a9e8785b7c0c56-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">prep</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M920.0,266.5 L928.0,254.5 912.0,254.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-9b11a3ff28404f4085a9e8785b7c0c56-0-5" stroke-width="2px" d="M1120,264.5 C1120,89.5 1445.0,89.5 1445.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-9b11a3ff28404f4085a9e8785b7c0c56-0-5" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M1120,266.5 L1112,254.5 1128,254.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-9b11a3ff28404f4085a9e8785b7c0c56-0-6" stroke-width="2px" d="M1295,264.5 C1295,177.0 1440.0,177.0 1440.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-9b11a3ff28404f4085a9e8785b7c0c56-0-6" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nn</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M1295,266.5 L1287,254.5 1303,254.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-9b11a3ff28404f4085a9e8785b7c0c56-0-7" stroke-width="2px" d="M945,264.5 C945,2.0 1450.0,2.0 1450.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-9b11a3ff28404f4085a9e8785b7c0c56-0-7" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">pobj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M1450.0,266.5 L1458.0,254.5 1442.0,254.5" fill="currentColor"/>
# </g>
# </svg></span>
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="c9b42f68d3584694a983b71164a640c5-0" class="displacy" width="1625" height="399.5" direction="ltr" style="max-width: none; height: 399.5px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="50">The</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="225">old</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="400">car</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="575">broke</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="750">down</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="925">in</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="925"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="1100">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="1275">car</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1275"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="1450">park .</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1450"></tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-c9b42f68d3584694a983b71164a640c5-0-0" stroke-width="2px" d="M70,264.5 C70,89.5 395.0,89.5 395.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-c9b42f68d3584694a983b71164a640c5-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,266.5 L62,254.5 78,254.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-c9b42f68d3584694a983b71164a640c5-0-1" stroke-width="2px" d="M245,264.5 C245,177.0 390.0,177.0 390.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-c9b42f68d3584694a983b71164a640c5-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">amod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M245,266.5 L237,254.5 253,254.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-c9b42f68d3584694a983b71164a640c5-0-2" stroke-width="2px" d="M420,264.5 C420,177.0 565.0,177.0 565.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-c9b42f68d3584694a983b71164a640c5-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M420,266.5 L412,254.5 428,254.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-c9b42f68d3584694a983b71164a640c5-0-3" stroke-width="2px" d="M595,264.5 C595,177.0 740.0,177.0 740.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-c9b42f68d3584694a983b71164a640c5-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">prt</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M740.0,266.5 L748.0,254.5 732.0,254.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-c9b42f68d3584694a983b71164a640c5-0-4" stroke-width="2px" d="M595,264.5 C595,89.5 920.0,89.5 920.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-c9b42f68d3584694a983b71164a640c5-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">prep</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M920.0,266.5 L928.0,254.5 912.0,254.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-c9b42f68d3584694a983b71164a640c5-0-5" stroke-width="2px" d="M1120,264.5 C1120,89.5 1445.0,89.5 1445.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-c9b42f68d3584694a983b71164a640c5-0-5" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M1120,266.5 L1112,254.5 1128,254.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-c9b42f68d3584694a983b71164a640c5-0-6" stroke-width="2px" d="M1295,264.5 C1295,177.0 1440.0,177.0 1440.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-c9b42f68d3584694a983b71164a640c5-0-6" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nn</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M1295,266.5 L1287,254.5 1303,254.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-c9b42f68d3584694a983b71164a640c5-0-7" stroke-width="2px" d="M945,264.5 C945,2.0 1450.0,2.0 1450.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-c9b42f68d3584694a983b71164a640c5-0-7" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">pobj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M1450.0,266.5 L1458.0,254.5 1442.0,254.5" fill="currentColor"/>
# </g>
# </svg></span>
# LAL vs Gold
# UAS: 1
# LAS: 1
# AJ vs Gold
# UAS: 1
# LAS: 1
# ----------------
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="4b1efa5363de4518937c694c05553406-0" class="displacy" width="1800" height="399.5" direction="ltr" style="max-width: none; height: 399.5px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="50">At</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="225">least</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="400">two</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="575">men</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="750">broke</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="925">in</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="925"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="1100">and</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="1275">stole</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1275"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="1450">my</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1450"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="1625">TV .</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1625"></tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-4b1efa5363de4518937c694c05553406-0-0" stroke-width="2px" d="M70,264.5 C70,177.0 215.0,177.0 215.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-4b1efa5363de4518937c694c05553406-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">advmod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,266.5 L62,254.5 78,254.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-4b1efa5363de4518937c694c05553406-0-1" stroke-width="2px" d="M245,264.5 C245,177.0 390.0,177.0 390.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-4b1efa5363de4518937c694c05553406-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">quantmod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M245,266.5 L237,254.5 253,254.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-4b1efa5363de4518937c694c05553406-0-2" stroke-width="2px" d="M420,264.5 C420,177.0 565.0,177.0 565.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-4b1efa5363de4518937c694c05553406-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">num</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M420,266.5 L412,254.5 428,254.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-4b1efa5363de4518937c694c05553406-0-3" stroke-width="2px" d="M595,264.5 C595,177.0 740.0,177.0 740.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
# ...
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">For</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="225">example</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="400">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="575">original</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="750">Brown</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="925">and</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="925"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="1100">C5</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="1275">tagsets</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1275"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="1450">include</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1450"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="1625">a</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1625"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="1800">separate</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1800"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="1975">tag</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1975"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="2150">for</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2150"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="2325">each</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2325"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="2500">of</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2500"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="2675">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2675"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="2850">different</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2850"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="3025">forms</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3025"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="3200">of</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3200"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="3375">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3375"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="3550">verbs</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3550"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="3725">do</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3725"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="3900">-LRB-</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3900"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="4075">e.g.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4075"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="4250">C5</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4250"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="4425">tag</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4425"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="4600">VDD</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4600"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="4775">for</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4775"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="4950">did</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4950"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="5125">and</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="5125"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="5300">VDG</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="5300"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="5151fa6ba291436c9f0fe720ef1e4858-0" class="displacy" width="6700" height="924.5" direction="ltr" style="max-width: none; height: 924.5px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="834.5">
#     <tspan class="displacy-word" fill="currentColor" x="50">For</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="834.5">
#     <tspan class="displacy-word" fill="currentColor" x="225">example</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="834.5">
#     <tspan class="displacy-word" fill="currentColor" x="400">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="834.5">
#     <tspan class="displacy-word" fill="currentColor" x="575">original</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="834.5">
#     <tspan class="displacy-word" fill="currentColor" x="750">Brown</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="834.5">
#     <tspan class="displacy-word" fill="currentColor" x="925">and</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="925"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="834.5">
#     <tspan class="displacy-word" fill="currentColor" x="1100">C5</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="834.5">
#     <tspan class="displacy-word" fill="currentColor" x="1275">tagsets</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1275"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="834.5">
#     <tspan class="displacy-word" fill="currentColor" x="1450">include</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1450"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="834.5">
#     <tspan class="displacy-word" fill="currentColor" x="1625">a</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1625"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="834.5">
#     <tspan class="displacy-word" fill="currentColor" x="1800">separate</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1800"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="834.5">
#     <tspan class="displacy-word" fill="currentColor" x="1975">tag</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1975"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="834.5">
#     <tspan class="displacy-word" fill="currentColor" x="2150">for</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2150"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="834.5">
#     <tspan class="displacy-word" fill="currentColor" x="2325">each</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2325"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="834.5">
#     <tspan class="displacy-word" fill="currentColor" x="2500">of</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2500"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="834.5">
#     <tspan class="displacy-word" fill="currentColor" x="2675">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2675"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="834.5">
#     <tspan class="displacy-word" fill="currentColor" x="2850">different</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2850"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="834.5">
#     <tspan class="displacy-word" fill="currentColor" x="3025">forms</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3025"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="834.5">
#     <tspan class="displacy-word" fill="currentColor" x="3200">of</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3200"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="834.5">
#     <tspan class="displacy-word" fill="currentColor" x="3375">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3375"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="834.5">
#     <tspan class="displacy-word" fill="currentColor" x="3550">verbs</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3550"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="834.5">
#     <tspan class="displacy-word" fill="currentColor" x="3725">do</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3725"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="834.5">
#     <tspan class="displacy-word" fill="currentColor" x="3900">-LRB-</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3900"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="834.5">
#     <tspan class="displacy-word" fill="currentColor" x="4075">e.g.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4075"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="834.5">
#     <tspan class="displacy-word" fill="currentColor" x="4250">C5</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4250"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="834.5">
#     <tspan class="displacy-word" fill="currentColor" x="4425">tag</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4425"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="834.5">
#     <tspan class="displacy-word" fill="currentColor" x="4600">VDD</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4600"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="834.5">
#     <tspan class="displacy-word" fill="currentColor" x="4775">for</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4775"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="834.5">
#     <tspan class="displacy-word" fill="currentColor" x="4950">did</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4950"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="834.5">
#     <tspan class="displacy-word" fill="currentColor" x="5125">and</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="5125"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="834.5">
#     <tspan class="displacy-word" fill="currentColor" x="5300">VDG</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="5300"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="834.5">
#     <tspan class="displacy-
# LAL vs Gold
# UAS: 0.5
# LAS: 0.5
# AJ vs Gold
# UAS: 0.6111111111111112
# LAS: 0.5833333333333334
# ----------------
# MEAN UAS LAL: 0.8082901554404145
# MEAN LAS LAL: 0.7512953367875648
# MEAN UAS AJ: 0.8031088082901554
# MEAN LAS AJ: 0.7512953367875648

# %% [markdown]
# #### Printing table for Latex

# %%
# Print a table for Latex that contains relations 
# for each parser and the gold standard
def print_table_latex(deps_g, head_g, words_g,
                      deps_1, head_1, words_1,
                      deps_2, head_2, words_2, n):
  # Header of the table
  table = ('\\begin{table*}[h] \n' +
           '\\centering \n' +
           '\\begin{tabular}{|c||cc||cc||cc|} \n' +
           '\\hline \n' +
           '{} & \\multicolumn{2}{c||}{\\textbf{GOLD}} & \\multicolumn{2}{c||}{\\textbf{LAL parser}} & \\multicolumn{2}{c|}{\\textbf{AJ parser}} \\\\ \n' +
           '\\textbf{Word} & \\textbf{Head} & \\textbf{Rel} & \\textbf{Head} & \\textbf{Rel} & \\textbf{Head} & \\textbf{Rel} \\\\ \n' +
           '\\hline \n')
  counter = 0
  for dg, hg, wg, d1, h1, w1, d2, h2, w2, in zip(deps_g, head_g, words_g,
                                                 deps_1, head_1, words_1,
                                                 deps_2, head_2, words_2):
    
    symbolg = ""
    symbol1 = ""
    symbol2 = ""
    #Ignore punct relations
    if dg != "punct":

      # Gold
      if hg == None: 
        # ROOT head
        hg_t = ""
      # symbol means the direction of the arc
      elif hg > counter:
        # left arc
        symbolg = "<"
        hg_t = words_g[hg]
      elif hg < counter:
        # right arc
        symbolg = ">"
        hg_t = words_g[hg]

      # LAL
      if h1 == None: 
        h1_t = ""
      elif h1 > counter:
        symbol1 = "<"
        h1_t = words_1[h1]
      elif h1 < counter:
        symbol1 = ">"
        h1_t = words_1[h1]

      # AJ
      if h2 == None: 
        h2_t = ""
      elif h2 > counter:
        symbol2 = "<"
        h2_t = words_2[h2]
      elif h2 < counter:
        symbol2 = ">"
        h2_t = words_2[h2]

      # New row
      table += f"{w1} & {symbolg}{hg_t} & {dg} & {symbol1}{h1_t} & {d1} & {symbol2}{h2_t} & {d2} \\\\ \n"
      table += '\\hline \n'
    counter += 1

  # Table footer
  table += ('\\end{tabular} \n \\caption{\\label{tab:dps' + 
            str(n) + '} \n' + 
           'Dependency parsing of sentence ' + str(n) +
           ' of all parsers and gold standard.} \n' +
           '\end{table*}')
  
  print(table)

# %%
# Print table for Latex
counter = 1
for word, deps_t, heads_t, sent, gold, gold_words in zip(words_to_use, new_dep_labels,
                                   new_dep_heads, dp_tree_p2, dp_gold_to_use, final_words_w_index):
  # Preprocessing of AJ predictions
  words2 = []
  deps2 = []
  heads2 = []
  for i in sent:
    words2 += [i.form]
    if i.deprel == 'root':
      deps2 += ['ROOT']
      heads2 += [None]
    else:
      deps2 += [i.deprel]
      heads2 += [i.head-1]
  
  # Print table
  print(f"%Sentence no. {counter}")
  print_table_latex(gold[0], gold[1], gold_words,
                    deps_t, heads_t, word,
                    deps2, heads2, words2, counter)
  counter += 1
  print()
# Out:
# %Sentence no. 1
# \begin{table*}[h]
# \centering
# \begin{tabular}{|c||cc||cc||cc|}
# \hline
# {} & \multicolumn{2}{c||}{\textbf{GOLD}} & \multicolumn{2}{c||}{\textbf{LAL parser}} & \multicolumn{2}{c|}{\textbf{AJ parser}} \\
# \textbf{Word} & \textbf{Head} & \textbf{Rel} & \textbf{Head} & \textbf{Rel} & \textbf{Head} & \textbf{Rel} \\
# \hline
# My & <aunt & poss & <aunt & poss & <aunt & poss \\
# \hline
# aunt & <opener & poss & <can & poss & <opener & poss \\
# \hline
# 's & >aunt & possessive & >aunt & possessive & >aunt & possessive \\
# \hline
# can & <opener & nn & <open & aux & <opener & dep \\
# \hline
# opener & <open & nsubj & >can & dep & <open & nsubj \\
# \hline
# can & <open & aux & <open & aux & <open & aux \\
# \hline
# open &  & ROOT &  & ROOT &  & ROOT \\
# \hline
# a & <drum & det & <drum & det & <drum & det \\
# \hline
# drum & >open & dobj & >open & dobj & >open & dobj \\
# \hline
# \end{tabular}
#  \caption{\label{tab:dps1}
# Dependency parsing of sentence 1 of all parsers and gold standard.}
# \end{table*}
#
# %Sentence no. 2
# \begin{table*}[h]
# \centering
# \begin{tabular}{|c||cc||cc||cc|}
# \hline
# {} & \multicolumn{2}{c||}{\textbf{GOLD}} & \multicolumn{2}{c||}{\textbf{LAL parser}} & \multicolumn{2}{c|}{\textbf{AJ parser}} \\
# \textbf{Word} & \textbf{Head} & \textbf{Rel} & \textbf{Head} & \textbf{Rel} & \textbf{Head} & \textbf{Rel} \\
# \hline
# The & <car & det & <car & det & <car & det \\
# \hline
# old & <car & amod & <car & amod & <car & amod \\
# \hline
# car & <broke & nsubj & <broke & nsubj & <broke & nsubj \\
# \hline
# broke &  & ROOT &  & ROOT &  & ROOT \\
# \hline
# down & >broke & prt & >broke & prt & >broke & prt \\
# \hline
# in & >broke & prep & >broke & prep & >broke & prep \\
# \hline
# the & <park & det & <park & det & <park & det \\
# \hline
# car & <park & nn & <park & nn & <park & nn \\
# \hline
# park & >in & pobj & >in & pobj & >in & pobj \\
# \hline
# \end{tabular}
#  \caption{\label{tab:dps2}
# Dependency parsing of sentence 2 of all parsers and gold standard.}
# \end{table*}
#
# %Sentence no. 3
# \begin{table*}[h]
# \centering
# \begin{tabular}{|c||cc||cc||cc|}
# \hline
# {} & \multicolumn{2}{c||}{\textbf{GOLD}} & \multicolumn{2}{c||}{\textbf{LAL parser}} & \multicolumn{2}{c|}{\textbf{AJ parser}} \\
# \textbf{Word} & \textbf{Head} & \textbf{Rel} & \textbf{Head} & \textbf{Rel} & \textbf{Head} & \textbf{Rel} \\
# \hline
# At & <least & advmod & <two & quantmod & <least & advmod \\
# \hline
# least & <two & quantmod & >At & mwe & <two & quantmod \\
# \hline
# two & <men & num & <men & num & <men & num \\
# \hline
# men & <broke & nsubj & <broke & nsubj & <broke & nsubj \\
# \hline
# broke &  & ROOT &  & ROOT &  & ROOT \\
# \hline
# in & >broke & prt & >broke & prt & >broke & prt \\
# \hline
# and & >broke & cc & >broke & cc & >broke & cc \\
# \hline
# stole & >broke & conj & >broke & conj & >broke & conj \\
# \hline
# my & <TV & poss & <TV & poss & <TV & poss \\
# \hline
# TV & >stole & dobj & >stole & dobj & >stole & dobj \\
# \hline
# \end{tabular}
#  \caption{\label{tab:dps3}
# Dependency parsing of sentence 3 of all parsers and gold standard.}
# \end{table*}
#
# %Sentence no. 4
# \begin{table*}[h]
# \centering
# \begin{tabular}{|c||cc||cc||cc|}
# \hline
# {} & \multicolumn{2}{c||}{\textbf{GOLD}} & \multicolumn{2}{c||}{\textbf{LAL parser}} & \multicolumn{2}{c|}{\textbf{AJ parser}} \\
# \textbf{Word} & \textbf{Head} & \textbf{Rel} & \textbf{Head} & \textbf{Rel} & \textbf{Head} & \textbf{Rel} \\
# \hline
# Kim & <broke & nsubj & <broke & nsubj & <broke & nsubj \\
# \hline
# and & >Kim & cc & >Kim & cc & >Kim & cc \\
# \hline
# Sandy & >Kim & conj & >Kim & conj & >Kim & conj \\
# \hline
# both & >Kim & preconj & <broke & dep & <broke & dep \\
# \hline
# broke &  & ROOT &  & ROOT &  & ROOT \\
# \hline
# up & >broke & prt & >broke & prt & >broke & prt \\
# \hline
# with & >broke & prep & >broke & prep & >broke & prep \\
# \hline
# their & <partner+s & poss & <partners & poss & <partners & poss \\
# \hline
# partners & >with & pobj & >with & pobj & >with & pobj \\
# \hline
# \end{tabular}
#  \caption{\label{tab:dps4}
# Dependency parsing of sentence 4 of all parsers and gold standard.}
# \end{table*}
#
# %Sentence no. 5
# \begin{table*}[h]
# \centering
# \begin{tabular}{|c||cc||cc||cc|}
# \hline
# {} & \multicolumn{2}{c||}{\textbf{GOLD}} & \multicolumn{2}{c||}{\textbf{LAL parser}} & \multicolumn{2}{c|}{\textbf{AJ parser}} \\
# \textbf{Word} & \textbf{Head} & \textbf{Rel} & \textbf{Head} & \textbf{Rel} & \textbf{Head} & \textbf{Rel} \\
# \hline
# The & <horse & det & <horse & det & <horse & det \\
# \hline
# horse & <escaped & nsubj & <escaped & nsubj & <escaped & nsubj \\
# \hline
# as & <well & mwe & <well & advmod & <well & advmod \\
# \hline
# well & >horse & cc & >horse & cc & >horse & cc \\
# \hline
# as & >well & mwe & >well & mwe & >well & mwe \\
# \hline
# the & <rabbit+s & det & <rabbits & det & <rabbits & det \\
# \hline
# rabbits & >horse & conj & >horse & conj & >horse & conj \\
# \hline
# which & >rabbit+s & ref & <wanted & dobj & <wanted & dobj \\
# \hline
# we & <want+ed & nsubj & <wanted & nsubj & <wanted & nsubj \\
# \hline
# wanted & >rabbit+s & rcmod & >rabbits & rcmod & >rabbits & rcmod \\
# \hline
# to & <eat & aux & <eat & aux & <eat & aux \\
# \hline
# eat & >want+ed & xcomp & >wanted & xcomp & >wanted & xcomp \\
# \hline
# has & <escaped & aux & <escaped & aux & <escaped & aux \\
# \hline
# escaped &  & ROOT &  & ROOT &  & ROOT \\
# \hline
# \end{tabular}
#  \caption{\label{tab:dps5}
# Dependency parsing of sentence 5 of all parsers and gold standard.}
# \end{table*}
#
# %Sentence no. 6
# \begin{table*}[h]
# \centering
# \begin{tabular}{|c||cc||cc||cc|}
# \hline
# {} & \multicolumn{2}{c||}{\textbf{GOLD}} & \multicolumn{2}{c||}{\textbf{LAL parser}} & \multicolumn{2}{c|}{\textbf{AJ parser}} \\
# \textbf{Word} & \textbf{Head} & \textbf{Rel} & \textbf{Head} & \textbf{Rel} & \textbf{Head} & \textbf{Rel} \\
# \hline
# It & <car & nsubj & <car & nsubj & <car & nsubj \\
# \hline
# was & <car & cop & <car & cop & <car & cop \\
# \hline
# my & <aunt & poss & <aunt & poss & <aunt & poss \\
# \hline
# aunt & <car & poss & <car & poss & <car & poss \\
# \hline
# 's & >aunt & possessive & >aunt & possessive & >aunt & possessive \\
# \hline
# car &  & ROOT &  & ROOT &  & ROOT \\
# \hline
# which & >car & ref & <sold & dobj & <sold & dobj \\
# \hline
# we & <sold & nsubj & <sold & nsubj & <sold & nsubj \\
# \hline
# sold & >car & rcmod & >car & rcmod & >car & rcmod \\
# \hline
# at & >sold & prep & >sold & prep & >sold & prep \\
# \hline
# auction & >at & pobj & >at & pobj & >at & pobj \\
# \hline
# last & <year & det & <year & amod & <year & amod \\
# \hline
# year & >sold & tmod & >sold & tmod & >sold & tmod \\
# \hline
# in & >year & prep & >sold & prep & >sold & prep \\
# \hline
# February & >in & pobj & >in & pobj & >in & pobj \\
# \hline
# \end{tabular}
#  \caption{\label{tab:dps6}
# Dependency parsing of sentence 6 of all parsers and gold standard.}
# \end{table*}
#
# %Sentence no. 7
# \begin{table*}[h]
# \centering
# \begin{tabular}{|c||cc||cc||cc|}
# \hline
# {} & \multicolumn{2}{c||}{\textbf{GOLD}} & \multicolumn{2}{c||}{\textbf{LAL parser}} & \multicolumn{2}{c|}{\textbf{AJ parser}} \\
# \textbf{Word} & \textbf{Head} & \textbf{Rel} & \textbf{Head} & \textbf{Rel} & \textbf{Head} & \textbf{Rel} \\
# \hline
# Natural & <disaster+s & amod & <disasters & amod & <disasters & amod \\
# \hline
# disasters & <occur & nsubj & <occur & nsubj & <occur & nsubj \\
# \hline
# storms & >disaster+s & appos & <hurricanes & nn & <hurricanes & nn \\
# \hline
# flooding & >storm+s & dep & <hurricanes & dep & <hurricanes & dep \\
# \hline
# hurricanes & >flood+ing & dep & >disasters & dep & >disasters & dep \\
# \hline
# occur &  & ROOT &  & ROOT &  & ROOT \\
# \hline
# infrequently & >occur & advmod & >occur & advmod & >occur & advmod \\
# \hline
# but & >occur & cc & >occur & cc & >occur & cc \\
# \hline
# cause & >occur & conj & >occur & conj & >occur & conj \\
# \hline
# devastation & >cause & dobj & >cause & dobj & >cause & dobj \\
# \hline
# that & <strain+s & nsubj & <strains & nsubj & <strains & nsubj \\
# \hline
# strains & >devastation & rcmod & >devastation & rcmod & >devastation & rcmod \\
# \hline
# resources & >strain+s & dobj & >strains & dobj & >strains & dobj \\
# \hline
# to & >strain+s & prep & >strains & prep & >strains & prep \\
# \hline
# breaking & <point & amod & <point & amod & <point & amod \\
# \hline
# point & >break+ing & pobj & >to & pobj & >to & pobj \\
# \hline
# \end{tabular}
#  \caption{\label{tab:dps7}
# Dependency parsing of sentence 7 of all parsers and gold standard.}
# \end{table*}
#
# %Sentence no. 8
# \begin{table*}[h]
# \centering
# \begin{tabular}{|c||cc||cc||cc|}
# \hline
# {} & \multicolumn{2}{c||}{\textbf{GOLD}} & \multicolumn{2}{c||}{\textbf{LAL parser}} & \multicolumn{2}{c|}{\textbf{AJ parser}} \\
# \textbf{Word} & \textbf{Head} & \textbf{Rel} & \textbf{Head} & \textbf{Rel} & \textbf{Head} & \textbf{Rel} \\
# \hline
# Letters & <rare & nsubj & <rare & nsubj & <rare & nsubj \\
# \hline
# delivered & >Letter+s & vmod & >Letters & vmod & >Letters & vmod \\
# \hline
# on & >deliver+ed & prep & >delivered & prep & >delivered & prep \\
# \hline
# time & >on & pobj & >on & pobj & >on & pobj \\
# \hline
# by & >deliver+ed & prep & >delivered & prep & >delivered & prep \\
# \hline
# old & <fashion+ed & amod & <fashioned & amod & <means & amod \\
# \hline
# fashioned & <means & amod & <means & amod & <means & amod \\
# \hline
# means & >by & pobj & >by & pobj & >by & pobj \\
# \hline
# are & <rare & cop & <rare & cop & <rare & cop \\
# \hline
# increasingly & <rare & advmod & <rare & advmod & <rare & advmod \\
# \hline
# rare &  & ROOT &  & ROOT &  & ROOT \\
# \hline
# so & >rare & dep & >rare & dep & >rare & dep \\
# \hline
# it & <well & nsubj & <well & nsubj & <is & nsubj \\
# \hline
# is & <well & cop & <well & cop & >rare & parataxis \\
# \hline
# as & <well & advmod & <well & advmod & <well & advmod \\
# \hline
# well & >rare & advcl & >rare & ccomp & >is & advmod \\
# \hline
# that & <option & mark & <option & mark & <option & mark \\
# \hline
# that & <option & nsubj & <option & nsubj & <option & nsubj \\
# \hline
# is & <option & cop & <option & cop & <option & cop \\
# \hline
# not & <option & neg & <option & neg & <option & neg \\
# \hline
# the & <option & det & <option & det & <option & det \\
# \hline
# only & <option & amod & <option & amod & <option & amod \\
# \hline
# option & >well & ccomp & >well & ccomp & >is & ccomp \\
# \hline
# available & >option & amod & >option & amod & >option & amod \\
# \hline
# \end{tabular}
#  \caption{\label{tab:dps8}
# Dependency parsing of sentence 8 of all parsers and gold standard.}
# \end{table*}
#
# %Sentence no. 9
# \begin{table*}[h]
# \centering
# \begin{tabular}{|c||cc||cc||cc|}
# \hline
# {} & \multicolumn{2}{c||}{\textbf{GOLD}} & \multicolumn{2}{c||}{\textbf{LAL parser}} & \multicolumn{2}{c|}{\textbf{AJ parser}} \\
# \textbf{Word} & \textbf{Head} & \textbf{Rel} & \textbf{Head} & \textbf{Rel} & \textbf{Head} & \textbf{Rel} \\
# \hline
# English & <has & nsubj & <has & nsubj & <has & nsubj \\
# \hline
# also & <has & advmod & <has & advmod & <has & advmod \\
# \hline
# has &  & ROOT &  & ROOT &  & ROOT \\
# \hline
# many & <word+s & amod & <words & amod & <words & amod \\
# \hline
# words & >has & dobj & >has & dobj & >has & dobj \\
# \hline
# of & >word+s & prep & >words & prep & >words & prep \\
# \hline
# more & <unique & amod & <function & amod & <unique & advmod \\
# \hline
# or & >more & cc & >more & cc & >more & cc \\
# \hline
# less & >more & conj & >more & conj & >more & conj \\
# \hline
# unique & <function & amod & <function & amod & <function & amod \\
# \hline
# function & >of & pobj & >of & pobj & >of & pobj \\
# \hline
# including & >word+s & vmod & >words & prep & >words & prep \\
# \hline
# interjections & >including & dobj & >including & pobj & >including & pobj \\
# \hline
# oh & >interjection+s & dep & >interjections & discourse & >interjections & discourse \\
# \hline
# ah & >interjection+s & dep & >oh & dep & >oh & dep \\
# \hline
# negatives & >interjection+s & conj & >interjections & conj & >interjections & conj \\
# \hline
# no & >negative+s & dep & >negatives & discourse & >negatives & discourse \\
# \hline
# not & >negative+s & dep & >no & dep & >no & dep \\
# \hline
# politeness & <marker+s & nn & <markers & nn & <markers & nn \\
# \hline
# markers & >interjection+s & conj & >interjections & conj & >interjections & conj \\
# \hline
# please & >marker+s & dep & <thank & discourse & <you & discourse \\
# \hline
# thank & >marker+s & dep & >markers & dep & <you & dep \\
# \hline
# you & >thank & dobj & >thank & dep & >markers & dep \\
# \hline
# and & >interjection+s & cc & >interjections & cc & >interjections & cc \\
# \hline
# the & <there & det & <there & det & <existential & det \\
# \hline
# existential & <there & amod & <there & amod & >interjections & conj \\
# \hline
# there & >interjection+s & conj & >interjections & conj & >existential & dep \\
# \hline
# there & <are & expl & <are & expl & <are & expl \\
# \hline
# are & >there & dep & >there & dep & >existential & dep \\
# \hline
# horses & >are & dobj & >are & nsubj & >are & nsubj \\
# \hline
# but & >horse+s & cc & >horses & cc & >horses & cc \\
# \hline
# not & <unicorn+s & neg & >horses & conj & <unicorns & neg \\
# \hline
# unicorns & >horse+s & conj & >horses & dep & >horses & conj \\
# \hline
# among & >interjection+s & prep & >there & prep & >existential & prep \\
# \hline
# others & >among & pobj & >among & pobj & >among & pobj \\
# \hline
# \end{tabular}
#  \caption{\label{tab:dps9}
# Dependency parsing of sentence 9 of all parsers and gold standard.}
# \end{table*}
#
# %Sentence no. 10
# \begin{table*}[h]
# \centering
# \begin{tabular}{|c||cc||cc||cc|}
# \hline
# {} & \multicolumn{2}{c||}{\textbf{GOLD}} & \multicolumn{2}{c||}{\textbf{LAL parser}} & \multicolumn{2}{c|}{\textbf{AJ parser}} \\
# \textbf{Word} & \textbf{Head} & \textbf{Rel} & \textbf{Head} & \textbf{Rel} & \textbf{Head} & \textbf{Rel} \\
# \hline
# The & <tagset & det & <tagset & det & <tagset & det \\
# \hline
# Penn & <tagset & nn & <tagset & nn & <tagset & nn \\
# \hline
# Treebank & <tagset & nn & <tagset & nn & <tagset & nn \\
# \hline
# tagset & <cull+ed & nsubjpass & <culled & nsubjpass & <culled & nsubjpass \\
# \hline
# was & <cull+ed & auxpass & <culled & auxpass & <culled & auxpass \\
# \hline
# culled &  & ROOT &  & ROOT &  & ROOT \\
# \hline
# from & >cull+ed & prep & >culled & prep & >culled & prep \\
# \hline
# the & <tagset & det & <tagset & det & <tagset & det \\
# \hline
# original & <tagset & amod & <tagset & amod & <tagset & amod \\
# \hline
# 87 & <tag & number & <tag & number & <tagset & num \\
# \hline
# tag & <tagset & nn & <tagset & amod & <tagset & nn \\
# \hline
# tagset & >from & pobj & >from & pobj & >from & pobj \\
# \hline
# for & >tagset & prep & >tagset & prep & >tagset & prep \\
# \hline
# the & <Corpus & det & <Corpus & det & <Corpus & det \\
# \hline
# Brown & <Corpus & nn & <Corpus & nn & <Corpus & nn \\
# \hline
# Corpus & >for & pobj & >for & pobj & >for & pobj \\
# \hline
# \end{tabular}
#  \caption{\label{tab:dps10}
# Dependency parsing of sentence 10 of all parsers and gold standard.}
# \end{table*}
#
# %Sentence no. 11
# \begin{table*}[h]
# \centering
# \begin{tabular}{|c||cc||cc||cc|}
# \hline
# {} & \multicolumn{2}{c||}{\textbf{GOLD}} & \multicolumn{2}{c||}{\textbf{LAL parser}} & \multicolumn{2}{c|}{\textbf{AJ parser}} \\
# \textbf{Word} & \textbf{Head} & \textbf{Rel} & \textbf{Head} & \textbf{Rel} & \textbf{Head} & \textbf{Rel} \\
# \hline
# For & <include & prep & <include & prep & <include & prep \\
# \hline
# example & >For & pobj & >For & pobj & >For & pobj \\
# \hline
# the & <Brown & det & <Brown & det & <Brown & det \\
# \hline
# original & <Brown & amod & <Brown & amod & <Brown & amod \\
# \hline
# Brown & <tagset+s & nn & <include & nsubj & <include & nsubj \\
# \hline
# and & >Brown & cc & >Brown & cc & >Brown & cc \\
# \hline
# C5 & >Brown & conj & <tagsets & nn & <tagsets & nn \\
# \hline
# tagsets & <include & nsubj & >Brown & conj & >Brown & conj \\
# \hline
# include &  & ROOT &  & ROOT &  & ROOT \\
# \hline
# a & <tag & det & <tag & det & <tag & det \\
# \hline
# separate & <tag & amod & <tag & amod & <tag & amod \\
# \hline
# tag & >include & dobj & >include & dobj & >include & dobj \\
# \hline
# for & >tag & prep & >tag & prep & >tag & prep \\
# \hline
# each & >for & pobj & >for & pobj & >for & pobj \\
# \hline
# of & >each & prep & >each & prep & >each & prep \\
# \hline
# the & <form+s & det & <forms & det & <forms & det \\
# \hline
# different & <form+s & amod & <forms & amod & <forms & amod \\
# \hline
# forms & >of & pobj & >of & pobj & >of & pobj \\
# \hline
# of & >form+s & prep & >forms & prep & >forms & prep \\
# \hline
# the & <verb+s & det & <verbs & det & <verbs & det \\
# \hline
# verbs & >of & pobj & >of & pobj & >of & pobj \\
# \hline
# do & >verb+s & appos & <for & dep & <VDD & dep \\
# \hline
# e.g. & >do & dep & <for & discourse & <VDD & dep \\
# \hline
# C5 & <tag & nn & <for & nn & <VDD & nn \\
# \hline
# tag & >e.g. & dep & <for & nn & <VDD & nn \\
# \hline
# VDD & >tag & nn & >tag & dep & >verbs & dep \\
# \hline
# for & >tag & prep & tag & prep & >VDD & prep \\
# \hline
# did & >for & pobj & tag & pobj & >for & pcomp \\
# \hline
# and & >tag & cc & >for & cc & >VDD & cc \\
# \hline
# VDG & <tag & nn & <for & nn & <tag & nn \\
# \hline
# tag & >tag & conj & >for & conj & >VDD & conj \\
# \hline
# for & >tag & prep & for & prep & >tag & prep \\
# \hline
# doing & >for & pobj & for & pcomp & >for & pobj \\
# \hline
# be & >do & conj & >for & conj & >verbs & conj \\
# \hline
# and & >do & cc & >for & cc & >verbs & cc \\
# \hline
# have & >do & conj & >for & conj & >verbs & conj \\
# \hline
# \end{tabular}
#  \caption{\label{tab:dps11}
# Dependency parsing of sentence 11 of all parsers and gold standard.}
# \end{table*}
